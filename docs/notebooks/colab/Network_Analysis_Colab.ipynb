# %% [markdown]
# <h2><i>kiara</i>: Network Analysis</h2>
#
# Welcome back! Now that we're comfortable with what <i>kiara</i> looks like and what it can do to help track your data and your research process, let's try out some of the digital analysis tools, starting with <b>Network Analysis</b>.
#
# <h2>Why Network Analysis?</h2>
#
# Network Analysis offers a computational and quantitative means to examine and explore relational objects, with proxies to measure structural roles and concepts such as power and influence. Doing so digitally - and at scale - also allows us to consider these kinds of questions with large amounts of material or documents that was not  heretofore manageable with qualitative or manual approaches.
#
# We won't get into any core network theories or its uses in the humanities here, as we're focused on the ways in which network analysis in <i>kiara</i> offers an interesting way to wrap the research process, and think about the decisions we're making and how to trace them. If you're interested in learning more about network analysis, or how to code using <a href="https://networkx.org">NetworkX</a>, the library currently used in these <i>kiara</i> modules, check out our recommended reading at the bottom.
#
# <h3>Getting Started</h3>
# <br>Let's start by double checking that we have all the required plugins and setting up an API for us to use <i>kiara</i>. We'll do this all in one go this time, but if you're unsure, feel free to head back to the <a href="http://dharpa.org/kiara.documentation/latest/workshop/workshop/">installation notebook</a> to look over this section again.

# %%
! pip install git+https://github.com/DHARPA-Project/kiara_plugin.dh_tagung_2023
# Out:
# Collecting git+https://github.com/DHARPA-Project/kiara_plugin.dh_tagung_2023
#   Cloning https://github.com/DHARPA-Project/kiara_plugin.dh_tagung_2023 to /private/var/folders/tk/5kdys8d96yz3rbx2849tksw5_8p9qv/T/pip-req-build-__x9ssyw
#   Running command git clone --filter=blob:none --quiet https://github.com/DHARPA-Project/kiara_plugin.dh_tagung_2023 /private/var/folders/tk/5kdys8d96yz3rbx2849tksw5_8p9qv/T/pip-req-build-__x9ssyw
#   Resolved https://github.com/DHARPA-Project/kiara_plugin.dh_tagung_2023 to commit ac3bdf2332edaf586b4f428460dffeef836be1e3
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: kiara-plugin.network-analysis==0.4.12 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (0.4.12)
# Requirement already satisfied: scipy==1.10.1 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (1.10.1)
# Requirement already satisfied: observable-jupyter==0.1.14 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (0.1.14)
# Requirement already satisfied: kiara-plugin.onboarding==0.4.3 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (0.4.3)
# Requirement already satisfied: kiara-plugin.tabular==0.4.25 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (0.4.25)
# Requirement already satisfied: kiara==0.4.39 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (0.4.39)
# Requirement already satisfied: matplotlib==3.7.1 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (3.7.1)
# Requirement already satisfied: tzlocal<5.0,>=2.1 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (4.3)
# Requirement already satisfied: filetype<2.0.0,>=1.0.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (1.2.0)
# Requirement already satisfied: httpx>=0.23.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (4.5.0)
# Requirement already satisfied: importlib-metadata<7.0.0,>=3.0.0.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (6.0.0)
# Requirement already satisfied: regex>=2022.4.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (2023.5.5)
# Requirement already satisfied: multiformats-config<0.3.0,>=0.2.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (0.2.0.post4)
# Requirement already satisfied: rich>=12.4.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (13.3.5)
# Requirement already satisfied: orjson==3.8.10 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (3.8.10)
# Requirement already satisfied: email-validator>=1.3.1 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (2.0.0.post2)
# Requirement already satisfied: jinja2>=3.0.1 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (3.1.2)
# Requirement already satisfied: mistune<3,>=2.0.3 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (2.0.5)
# Requirement already satisfied: docstring-parser>=0.15.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (0.15)
# Requirement already satisfied: multiformats<0.3.0,>=0.2.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (0.2.1)
# Requirement already satisfied: pyzmq>=25.0.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (25.0.2)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.4 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (1.4.4)
# Requirement already satisfied: boltons>=21.0.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (23.0.0)
# Requirement already satisfied: networkx<4.0,>=3.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (3.1)
# Requirement already satisfied: pp-ez>=0.2.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (0.2.0)
# Requirement already satisfied: stevedore<6.0.0,>=5.0.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (5.1.0)
# Requirement already satisfied: mmhash3>=3.0.1 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (3.0.1)
# Requirement already satisfied: pydantic<2.0.0,>=1.10.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (1.10.7)
# Requirement already satisfied: dpath>=2.0.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (2.1.6)
# Requirement already satisfied: structlog>=21.5.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (23.1.0)
# Requirement already satisfied: dag-cbor<0.4.0,>=0.3.2 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (0.3.2)
# Requirement already satisfied: bidict>=0.21.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (0.22.1)
# Requirement already satisfied: pytz>=2022.6 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (2022.7)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (2.4.0)
# Requirement already satisfied: alembic>=1.7.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (1.11.1)
# Requirement already satisfied: humanfriendly>=10.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (10.0)
# Requirement already satisfied: click>=7.0.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (8.1.3)
# Requirement already satisfied: deepdiff<7.0.0,>=6.0.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (6.3.0)
# Requirement already satisfied: ruamel.yaml<0.18.0,>=0.17.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (0.17.26)
# Requirement already satisfied: fasteners>=0.18 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (0.18)
# Requirement already satisfied: distro>=1.6.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (1.8.0)
# Requirement already satisfied: rich-click>=1.0.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (1.6.1)
# Requirement already satisfied: pyzenodo3>=1.0.2 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara-plugin.onboarding==0.4.3->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (1.0.2)
# Requirement already satisfied: kiara-plugin.core-types>=0.4.16 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara-plugin.onboarding==0.4.3->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (0.4.17)
# Requirement already satisfied: patool in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara-plugin.onboarding==0.4.3->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (1.12)
# Requirement already satisfied: pyarrow>=12.0.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara-plugin.tabular==0.4.25->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (12.0.0)
# Requirement already satisfied: polars>=0.17.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara-plugin.tabular==0.4.25->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (0.17.14)
# Requirement already satisfied: sqlalchemy-utc>=0.10.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara-plugin.tabular==0.4.25->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (0.14.0)
# Requirement already satisfied: sqlite-utils==3.30 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara-plugin.tabular==0.4.25->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (3.30)
# Requirement already satisfied: duckdb<0.8.0,>=0.7.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara-plugin.tabular==0.4.25->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (0.7.1)
# Requirement already satisfied: sqlalchemy>=2.0.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara-plugin.tabular==0.4.25->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (2.0.15)
# Requirement already satisfied: sqlalchemy-utils>=0.38.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara-plugin.tabular==0.4.25->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (0.41.1)
# Requirement already satisfied: pandas>=1.4.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from kiara-plugin.tabular==0.4.25->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (2.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from matplotlib==3.7.1->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from matplotlib==3.7.1->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from matplotlib==3.7.1->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from matplotlib==3.7.1->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (1.0.7)
# Requirement already satisfied: numpy>=1.20 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from matplotlib==3.7.1->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (1.24.3)
# Requirement already satisfied: cycler>=0.10 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from matplotlib==3.7.1->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from matplotlib==3.7.1->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (4.39.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from matplotlib==3.7.1->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (5.12.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from matplotlib==3.7.1->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (9.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from matplotlib==3.7.1->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (23.0)
# Requirement already satisfied: click-default-group-wheel in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from sqlite-utils==3.30->kiara-plugin.tabular==0.4.25->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (1.2.2)
# Requirement already satisfied: tabulate in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from sqlite-utils==3.30->kiara-plugin.tabular==0.4.25->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (0.9.0)
# Requirement already satisfied: sqlite-fts4 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from sqlite-utils==3.30->kiara-plugin.tabular==0.4.25->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (1.0.3)
# Requirement already satisfied: Mako in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from alembic>=1.7.0->kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (1.2.4)
# Requirement already satisfied: typing-validation in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from dag-cbor<0.4.0,>=0.3.2->kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (1.0.0.post2)
# Requirement already satisfied: ordered-set<4.2.0,>=4.0.2 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from deepdiff<7.0.0,>=6.0.0->kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (4.1.0)
# Requirement already satisfied: idna>=2.0.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from email-validator>=1.3.1->kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (3.4)
# Requirement already satisfied: dnspython>=2.0.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from email-validator>=1.3.1->kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (2.3.0)
# Requirement already satisfied: httpcore<0.18.0,>=0.15.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from httpx>=0.23.0->kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (0.17.1)
# Requirement already satisfied: sniffio in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from httpx>=0.23.0->kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (1.2.0)
# Requirement already satisfied: certifi in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from httpx>=0.23.0->kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (2023.5.7)
# Requirement already satisfied: zipp>=0.5 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from importlib-metadata<7.0.0,>=3.0.0.0->kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (3.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from jinja2>=3.0.1->kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (2.1.1)
# Requirement already satisfied: bases in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from multiformats<0.3.0,>=0.2.0->kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (0.2.1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from pandas>=1.4.0->kiara-plugin.tabular==0.4.25->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib==3.7.1->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (1.16.0)
# Requirement already satisfied: requests in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from pyzenodo3>=1.0.2->kiara-plugin.onboarding==0.4.3->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (2.29.0)
# Requirement already satisfied: Beautifulsoup4 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from pyzenodo3>=1.0.2->kiara-plugin.onboarding==0.4.3->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (4.12.2)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from rich>=12.4.0->kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (2.15.1)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from rich>=12.4.0->kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (2.2.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from ruamel.yaml<0.18.0,>=0.17.0->kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (0.2.7)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from sqlalchemy>=2.0.0->kiara-plugin.tabular==0.4.25->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (2.0.2)
# Requirement already satisfied: setuptools in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from sqlalchemy-utc>=0.10.0->kiara-plugin.tabular==0.4.25->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (66.0.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from stevedore<6.0.0,>=5.0.0->kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (5.11.1)
# Requirement already satisfied: pytz-deprecation-shim in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from tzlocal<5.0,>=2.1->kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (0.1.0.post0)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from httpcore<0.18.0,>=0.15.0->httpx>=0.23.0->kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (0.14.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from httpcore<0.18.0,>=0.15.0->httpx>=0.23.0->kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (3.5.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=12.4.0->kiara==0.4.39->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (0.1.2)
# Requirement already satisfied: soupsieve>1.2 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from Beautifulsoup4->pyzenodo3>=1.0.2->kiara-plugin.onboarding==0.4.3->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (2.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from requests->pyzenodo3>=1.0.2->kiara-plugin.onboarding==0.4.3->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (1.26.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/helena.jaskov/opt/anaconda3/envs/kiara_berlin/lib/python3.9/site-packages (from requests->pyzenodo3>=1.0.2->kiara-plugin.onboarding==0.4.3->kiara-plugin.dh-tagung-2023==0.1.dev57+gac3bdf2) (2.0.4)

# %%
import networkx as nx
import os
import matplotlib.pyplot as plt
from kiara.api import KiaraAPI
kiara = KiaraAPI.instance()

# %% [markdown]
# ### Data
# Next we set up the filepaths for the data that we are going to use in this notebook. It is located in the same directory as the two jupyter notebooks are. You can find both files under 'data'. You will learn more about its contents later on.

# %%
csv_file_path = "CKCC.csv"
gml_file_path = "lesmis.gml"

# %% [markdown]
# Great, we're all set up. We're going to import some data again like in the first notebook, but this time we're going to use a local file, using the kiara function `import.local.file`. We're using sample data again here, but you can also use this function to import your own data in the future.
#
# The data we're using here is a sample taken from the <b>Circulation of Knowledge and Learned Practices in the 17th-century Dutch Republic (CKCC)</b> dataset collated by the Huygens Institute in the Netherlands and available on the 'LetterSampo' portal created by the Reassembling the Republic of Letters project team. For more on these projects see <a href="https://seco.cs.aalto.fi/projects/rrl/">here</a>.
#
# The CKCC collection features around 20,000 letters written by and to 17th century scholars in the Dutch republic. Using quantitative network analysis on this dataset might offer insights into the most prolific writer in the dataset, which actor connected the most people, or who operated in closely knit writing groups. Although we can also use network analysis to explore or 'map' our datasets if we don't know much about them, in this notebook the research questions and module parameters have been built around and defined by the information we already have about the data. It's important that we acknowledge this now as a core factor in the decisions already made for this process, but we'll also return to this throughout the notebook.
#
# Let's use the <i>kiara</i> function `import.local.file` then to access our datset, specifying the path to the csv file in our <span style="color:green">inputs</span> and saving the <span style="color:red">outputs</span> of the function as '<b>CKCC</b>'. Here we're indicating the 'csv_file_path' variable we have defined above. If it's stored somewhere else, we need to specify the full file path. (If you are using a file path and not a variable, remember to surround it with quotes like this for example: "/Users/some.user/Documents/my_csvfile.csv"). Alternatively, we can use the `download.file` module used in the <b>Hello Kiara</b> notebook.

# %%
CKCC = kiara.run_job('import.local.file', inputs={'path': csv_file_path})
CKCC
# Out:
# ╭──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                                          │
# │   field   value                                                                                                                          │
# │  ──────────────────────────────────────────────────────────────────────────────────                                                      │
# │   file    Source,Target                                                                                                                  │
# │           "Charas, Moyse, 1619-1698","Huygens, Christiaan, 1629-1695"                                                                    │
# │           "Hartzwich, Peter, fl. 1632","Groot, Hugo de, 1583-1645"                                                                       │
# │           "Heinsius, Daniel, 1580-1655","Groot, Hugo de, 1583-1645"                                                                      │
# │           "Heinsius, Daniel, 1580-1655","Groot, Hugo de, 1583-1645"                                                                      │
# │           "Heinsius, Daniel, 1580-1655","Groot, Hugo de, 1583-1645"                                                                      │
# │           "Heinsius, Daniel, 1580-1655","Groot, Hugo de, 1583-1645"                                                                      │
# │           "Heinsius, Daniel, 1580-1655","Groot, Hugo de, 1583-1645"                                                                      │
# │           "Heinsius, Daniel, 1580-1655","Groot, Hugo de, 1583-1645"                                                                      │
# │           "Heinsius, Daniel, 1580-1655","Groot, Hugo de, 1583-1645"                                                                      │
# │           "Heinsius, Daniel, 1580-1655","Groot, Hugo de, 1583-1645"                                                                      │
# │           "Heinsius, Daniel, 1580-1655","Groot, Hugo de, 1583-1645"                                                                      │
# │           "Heinsius, Daniel, 1580-1655","Groot, Hugo de, 1583-1645"                                                                      │
# │           "Heinsius, Daniel, 1580-1655","Huygens, Constantijn, 1596-1687"                                                                │
# │           "Heinsius, Daniel, 1580-1655","Huygens, Constantijn, 1596-1687"                                                                │
# │           "Heinsius, Nicolaas, 1620-1681","Huygens, Christiaan, 1629-1695"                                                               │
# │           "Heinsius, Nicolaas, 1620-1681","Dati, Carlo Roberto, 1619-1676"                                                               │
# │           "Heinsius, Nicolaas, 1620-1681","Dati, Carlo Roberto, 1619-1676"                                                               │
# │           "Heinsius, Nicolaas, 1620-1681","Boulliau, Ismaël, 1605-1694"                                                                  │
# │           "Heinsius, Nicolaas, 1620-1681","Boulliau, Ismaël, 1605-1694"                                                                  │
# │           "Heinsius, Nicolaas, 1620-1681","Dati, Carlo Roberto, 1619-1676"                                                               │
# │           "Heinsius, Nicolaas, 1620-1681","Dati, Carlo Roberto, 1619-1676"                                                               │
# │           "Heinsius, Nicolaas, 1620-1681","Dati, Carlo Roberto, 1619-1676"                                                               │
# │           "Heinsius, Nicolaas, 1620-1681","Dati, Carlo Roberto, 1619-1676"                                                               │
# │           "Heinsius, Nicolaas, 1620-1681","Gronovius, Johann Frederick, 1611-1671"                                                       │
# │           "Heinsius, Nicolaas, 1620-1681","Huygens, Christiaan, 1629-1695"                                                               │
# │           "Heinsius, Nicolaas, 1620-1681","Dati, Carlo Roberto, 1619-1676"                                                               │
# │           "Heinsius, Nicolaas, 1620-1681","Chapelain, Jean, 1595-1674"                                                                   │
# │           "Heinsius, Nicolaas, 1620-1681","Huygens, Christiaan, 1629-1695"                                                               │
# │           "Heinsius, Nicolaas, 1620-1681","Huygens, Christiaan, 1629-1695"                                                               │
# │           "Heinsius, Nicolaas, 1620-1681","Huygens, Christiaan, 1629-1695"                                                               │
# │           "Heinsius, Nicolaas, 1620-1681","Huygens, Christiaan, 1629-1695"                                                               │
# │           "Heinsius, Nicolaas, 1620-1681","Huygens, Christiaan, 1629-1695"                                                               │
# │           "Heinsius, Nicolaas, 1620-1681","Dati, Carlo Roberto, 1619-1676"                                                               │
# │           "Heinsius, Nicolaas, 1620-1681","Huygens, Christiaan, 1629-1695"                                                               │
# │           ...                                                                                                                            │
# │                                                                                                                                          │
# │           ...                                                                                                                            │
# │                                                                                                                                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# <h2>Creating a Network</h2>
#
# Time to make our network from this data. Let's have another look at the <i>kiara</i> modules to find something that will allow us to build a network.

# %%
kiara.list_operation_ids()
# Out:
# ['assemble.network_data.from.files',
#  'assemble.network_data.from.tables',
#  'compute.modularity_group',
#  'create.betweenness_rank_list',
#  'create.closeness_rank_list',
#  'create.cut_point_list',
#  'create.database.from.file',
#  'create.database.from.file_bundle',
#  'create.database.from.table',
#  'create.degree_rank_list',
#  'create.eigenvector_rank_list',
#  'create.network_data.from.file',
#  'create.table.from.file',
#  'create.table.from.file_bundle',
#  'date.check_range',
#  'date.extract_from_string',
#  'download.file',
#  'download.file_bundle',
#  'export.file.as.file',
#  'export.network_data.as.csv_files',
#  'export.network_data.as.graphml_file',
#  'export.network_data.as.sql_dump',
#  'export.network_data.as.sqlite_db',
#  'export.table.as.csv_file',
#  'extract.date_array.from.table',
#  'file_bundle.pick.file',
#  'file_bundle.pick.sub_folder',
#  'import.database.from.local_file_path',
#  'import.file',
#  'import.file_bundle',
#  'import.local.file',
#  'import.local.file_bundle',
#  'import.network_data.from.local_file_paths',
#  'import.table.from.local_file_path',
#  'import.table.from.local_folder_path',
#  'list.contains',
#  'logic.and',
#  'logic.nand',
#  'logic.nor',
#  'logic.not',
#  'logic.or',
#  'logic.xor',
#  'network_data.extract_largest_component',
#  'onboard.gml_file',
#  'onboard.zenodo_record',
#  'parse.date_array',
#  'query.database',
#  'query.table',
#  'string_filter.tokens',
#  'table.pick.column',
#  'table_filter.drop_columns',
#  'table_filter.select_columns',
#  'table_filter.select_rows']

# %% [markdown]
# The top one looks great. Let's have a look what we need with the function `assemble.network_data.from.tables` using `kiara.retrieve_operation_info` once more.

# %%
kiara.retrieve_operation_info('assemble.network_data.from.tables')
# Out:
#
#  Author(s)
#                      Lena Jaskov         helena.jaskov@uni.lu
#                      Markus Binsteiner   markus@frkl.io
#
#  Context
#                      Tags         network_analysis
#                      Labels       package: kiara_plugin.network_analysis
#                      References   source_repo: ]8;id=735585;https://github.com/DHARPA-Project/kiara_plugin.network_analysis\https://github.com/DHARPA-Project/kiara_plugin.network_analysis]8;;\
#                                   documentation: ]8;id=855731;https://DHARPA-Project.github.io/kiara_plugin.network_analysis/\https://DHARPA-Project.github.io/kiara_plugin.network_analysis/]8;;\
#
#  Operation details
#                      Documentation   Create a network_data instance from one or two tables.
#
#                                      This module needs at least one table as input, providing the edges of the resulting network data
#                                      set.
#                                      If no further table is created, basic node information will be automatically created by using unique
#                                      values from
#                                      the edges source and target columns.
#
#                      Inputs
#                                        field name           type     description                            Required   Default
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        edges                table    A table that contains the edges        yes        -- no default --
#                                                                      data.
#                                        source_column_name   string   The name of the source column name     no         source
#                                                                      in the edges table.
#                                        target_column_name   string   The name of the target column name     no         target
#                                                                      in the edges table.
#                                        edges_column_map     dict     An optional map of original column     no         -- no default --
#                                                                      name to desired.
#                                        nodes                table    A table that contains the nodes        no         -- no default --
#                                                                      data.
#                                        id_column_name       string   The name (before any potential         no         id
#                                                                      column mapping) of the node-table
#                                                                      column that contains the node
#                                                                      identifier (used in the edges
#                                                                      table).
#                                        label_column_name    string   The name of a column that contains     no         -- no default --
#                                                                      the node label (before any potential
#                                                                      column name mapping). If not
#                                                                      specified, the value of the id value
#                                                                      will be used as label.
#                                        nodes_column_map     dict     An optional map of original column     no         -- no default --
#                                                                      name to desired.
#
#
#                      Outputs
#                                        field name     type           description
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        network_data   network_data   The network/graph data.

# %% [markdown]
# Like other network analysis tools, <i>kiara</i> first needs the data as an edge table. This means we first have to transform the csv file we imported earlier into a table before we can create the network data. Let's start by using the `create.table.from.file` function that we used in the first notebook and storing this as our <b>edges</b>, then use this to create our network data using the `assemble.network_data.from.tables` that we just read about. In this, we are defining two different sets of <span style="color:green">inputs</span>, overriding the first variable once we have used it to create our table.
#
# If we want, we can also import a separate table with the nodes in, but this is optional, and for the moment let's stick with just the edge table. We'll store this again at the end in the variable <b>CKCC</b> for us to use again in a bit.
#
# First check the <span style="color:green">inputs</span> requirements for the `create.table.from.file` function, just to be sure:

# %%
kiara.retrieve_operation_info('create.table.from.file')
# Out:
#
#  Author(s)
#                      Markus Binsteiner   markus@frkl.io
#
#  Context
#                      Tags         tabular
#                      Labels       package: kiara_plugin.tabular
#                      References   source_repo: ]8;id=162266;https://github.com/DHARPA-Project/kiara_plugin.tabular\https://github.com/DHARPA-Project/kiara_plugin.tabular]8;;\
#                                   documentation: ]8;id=22659;https://DHARPA-Project.github.io/kiara_plugin.tabular/\https://DHARPA-Project.github.io/kiara_plugin.tabular/]8;;\
#
#  Operation details
#                      Documentation   Create a table from a file, trying to auto-determine the format of said file.
#
#                      Inputs
#                                        field name            type      description                          Required   Default
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        file                  file      The source value (of type 'file').   yes        -- no default --
#                                        first_row_is_header   boolean   Whether the first row of the file    no         -- no default --
#                                                                        is a header row. If not provided,
#                                                                        kiara will try to auto-determine.
#
#
#                      Outputs
#                                        field name   type    description
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        table        table   The result value (of type 'table').

# %%
inputs = {
    "file": CKCC['file'],
    "first_row_is_header": True
}

outputs = kiara.run_job('create.table.from.file', inputs=inputs)

edges = outputs['table']

inputs = {
    'edges': edges,
    'source_column_name': 'Source',
    'target_column_name': 'Target'
}

CKCC = kiara.run_job('assemble.network_data.from.tables', inputs=inputs)
CKCC
# Out:
# ╭──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                                          │
# │   field          value                                                                                                                   │
# │  ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────              │
# │   network_data                                                                                                                           │
# │                  Table: edges                                                                                                            │
# │                                                                                                                                          │
# │                    source                                              target                                                            │
# │                   ───────────────────────────────────────────────────────────────────────────────────────────────────                    │
# │                    Charas, Moyse, 1619-1698                            Huygens, Christiaan, 1629-1695                                    │
# │                    Hartzwich, Peter, fl. 1632                          Groot, Hugo de, 1583-1645                                         │
# │                    Heinsius, Daniel, 1580-1655                         Groot, Hugo de, 1583-1645                                         │
# │                    Heinsius, Daniel, 1580-1655                         Groot, Hugo de, 1583-1645                                         │
# │                    Heinsius, Daniel, 1580-1655                         Groot, Hugo de, 1583-1645                                         │
# │                    Heinsius, Daniel, 1580-1655                         Groot, Hugo de, 1583-1645                                         │
# │                    Heinsius, Daniel, 1580-1655                         Groot, Hugo de, 1583-1645                                         │
# │                    Heinsius, Daniel, 1580-1655                         Groot, Hugo de, 1583-1645                                         │
# │                    Heinsius, Daniel, 1580-1655                         Groot, Hugo de, 1583-1645                                         │
# │                    Heinsius, Daniel, 1580-1655                         Groot, Hugo de, 1583-1645                                         │
# │                    Heinsius, Daniel, 1580-1655                         Groot, Hugo de, 1583-1645                                         │
# │                    Heinsius, Daniel, 1580-1655                         Groot, Hugo de, 1583-1645                                         │
# │                    Heinsius, Daniel, 1580-1655                         Huygens, Constantijn, 1596-1687                                   │
# │                    Heinsius, Daniel, 1580-1655                         Huygens, Constantijn, 1596-1687                                   │
# │                    Heinsius, Nicolaas, 1620-1681                       Huygens, Christiaan, 1629-1695                                    │
# │                    Heinsius, Nicolaas, 1620-1681                       Dati, Carlo Roberto, 1619-1676                                    │
# │                    ...                                                 ...                                                               │
# │                    ...                                                 ...                                                               │
# │                    Zeeland, States of                                  Groot, Hugo de, 1583-1645                                         │
# │                    Zeeland, States of                                  Groot, Hugo de, 1583-1645                                         │
# │                    Zeeland, States of                                  Groot, Hugo de, 1583-1645                                         │
# │                    Zeeland, States of                                  Court of Holland, Zeeland and West Friesland,                     │
# │                    Zeeland, States of                                  Groot, Hugo de, 1583-1645                                         │
# │                    Zeeland, States of                                  Court of Holland, Zeeland and West Friesland,                     │
# │                    Colmar, government of                               Groot, Hugo de, 1583-1645                                         │
# │                    Colmar, government of                               Groot, Hugo de, 1583-1645                                         │
# │                    Colmar, government of                               Groot, Hugo de, 1583-1645                                         │
# │                    Alsace, knighthood of                               Groot, Hugo de, 1583-1645                                         │
# │                    Amsterdam, Committed Councils to the Admiralty of   Groot, Hugo de, 1583-1645                                         │
# │                    Holland, Committed Councils of                      Groot, Hugo de, 1583-1645                                         │
# │                    Dutch East India Company, Zeeland Chamber of the    Groot, Hugo de, 1583-1645                                         │
# │                    Orléans, administration of the German Nation at     Groot, Hugo de, 1583-1645                                         │
# │                    Friesland, Members of the States of                 Unknown                                                           │
# │                    Leiden University                                   Descartes, René, 1596-1650                                        │
# │                                                                                                                                          │
# │                  Table: nodes                                                                                                            │
# │                                                                                                                                          │
# │                    id                                                  label                                                             │
# │                   ───────────────────────────────────────────────────────────────────────────────────────────────────────                │
# │                    Heinsius, Nicolaas, 1620-1681                       Heinsius, Nicolaas, 1620-1681                                     │
# │                    Vogelaer, Marcus, b.1589                            Vogelaer, Marcus, b.1589                                          │
# │                    Colbert, Jean-Baptiste, 1619-1683                   Colbert, Jean-Baptiste, 1619-1683                                 │
# │                    Thorius, Raphael, 1560-1625                         Thorius, Raphael, 1560-1625                                       │
# │                    Aubespine, François, 1584-1670                      Aubespine, François, 1584-1670                                    │
# │                    Joachimi, Albert, 1560-1654                         Joachimi, Albert, 1560-1654                                       │
# │                    Zuerius, Jacob, fl. 1632-1643                       Zuerius, Jacob, fl. 1632-1643                                     │
# │                    Vincent, fl. 1636                                   Vincent, fl. 1636                                                 │
# │                    Ayala, Ferdinand, fl. 1637-1641                     Ayala, Ferdinand, fl. 1637-1641                                   │
# │                    Bouricius, Hector, 1593-1636                        Bouricius, Hector, 1593-1636                                      │
# │                    Balzac, Jean Louis Guez, 1597-1654                  Balzac, Jean Louis Guez, 1597-1654                                │
# │                    Brasset, Jean, b.1591                               Brasset, Jean, b.1591                                             │
# │                    Sandilands, James, fl. 1637-1638                    Sandilands, James, fl. 1637-1638                                  │
# │                    Hoefnagel, Susanna, 1561-1633                       Hoefnagel, Susanna, 1561-1633                                     │
# │                    Gronovius, Johann Frederick, 1611-1671              Gronovius, Johann Frederick, 1611-1671                            │
# │                    Pauw, Adriaan, 1585-1653                            Pauw, Adriaan, 1585-1653                                          │
# │                    ...                                                 ...                                                               │
# │                    ...                                                 ...                                                               │
# │                    Schieland, bailiff and dike warden of, fl. 1644     Schieland, bailiff and dike warden of, fl. 1644                   │
# │                    Jan Harmensz, d.1660                                Jan Harmensz, d.1660                                              │
# │                    Oudewater, mayors and governors of                  Oudewater, mayors and governors of                                │
# │                    Drenthe, sheriff and deputies of                    Drenthe, sheriff and deputies of                                  │
# │                    Zaltbommel, government of, fl. 1638-1645            Zaltbommel, government of, fl. 1638-1645                          │
# │                    Oudart, Robert, b.1581                              Oudart, Robert, b.1581                                            │
# │                    Pijnacker, Cornelis, 1570-1645                      Pijnacker, Cornelis, 1570-1645                                    │
# │                    Sande, Johan van den, 1568-1638                     Sande, Johan van den, 1568-1638                                   │
# │                    Suytwijck, Pieter, fl. 1639                         Suytwijck, Pieter, fl. 1639                                       │
# │                    Dordrecht, mayors and governors of                  Dordrecht, mayors and governors of                                │
# │                    Zwolle, government of, fl. 1644                     Zwolle, government of, fl. 1644                                   │
# │                    Jan Hendriken, d.1660                               Jan Hendriken, d.1660                                             │
# │                    Amsterdam, Committed Councils to the Admiralty of   Amsterdam, Committed Councils to the Admiralty of                 │
# │                    Friesland, Members of the States of                 Friesland, Members of the States of                               │
# │                    Dutch East India Company, Zeeland Chamber of the    Dutch East India Company, Zeeland Chamber of the                  │
# │                    Alsace, knighthood of                               Alsace, knighthood of                                             │
# │                                                                                                                                          │
# │                                                                                                                                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# Great - this has made a <i>kiara</i> network data object, and the output is showing the edge table and node table for the network. As we didn't give it a node table to start with this, it has extracted the information for the nodes from the edges instead.
#
# As we can see, some of the edges are listed more than once, where more than one letter was written from one person to another. There's obviously more information about the network than just a list of edges and nodes then - let's find out some more information about our network object then.

# %% [markdown]
# <h2>Network Data</h2>
#
# Let's start by having a look at the information for our network using the `get_property_data` function. As we're querying the `network_data` part of our network object, we'll save this as <b>CKCC</b> for the moment.

# %%
CKCC = CKCC['network_data']
CKCC.get_property_data('metadata.graph_properties')
# Out:
#
#   number_of_nodes            1926
#   properties_by_graph_type   {
#                                "graph_type": "directed",
#                                "number_of_edges": 2942
#                              }
#                              {
#                                "graph_type": "undirected",
#                                "number_of_edges": 2332
#                              }
#                              {
#                                "graph_type": "directed-multi",
#                                "number_of_edges": 20029
#                              }
#                              {
#                                "graph_type": "undirected-multi",
#                                "number_of_edges": 20029
#                              }
#   number_of_self_loops       92
#   number_of_parallel_edges   17087

# %% [markdown]
# Doing this gives us the total number of nodes, but also gives us an idea of the different kind of graphs we might chose to use for this dataset - <b>Directed</b>, <b>Undirected</b>, <b>Multi-Directed</b>, and <b>Multi-Undirected</b>. We spotted earlier that some of the edges were listed more than once, but this function tells us that there are a total of 17,087 parallel edges - we can decide what we'll do with those in a little bit, but it's good to know that they make up quite a lot of our data. It also shows us that there's a large number of self-loops - this is unusual in epistolarly collections, so this function might also flag up some errors or inconsistencies in our dataset that we can go back to at some point.
#
# Having this kind of information accessible means we can make more informed decisions about the next steps that might work with our research or digital analysis, especially those that are sometimes automated for us.
#
# Let's get some more information about the network as a whole then, using the `network_data.extract_largest_component` function. This works out how many different distinct components there are in a network, and also gives us the largest component on its own. We'll have a quick look at how it works first.

# %%
kiara.retrieve_operation_info('network_data.extract_largest_component')
# Out:
#
#  Author(s)
#                      Lena Jaskov         helena.jaskov@uni.lu
#                      Markus Binsteiner   markus@frkl.io
#
#  Context
#                      Tags         network_analysis
#                      Labels       package: kiara_plugin.network_analysis
#                      References   source_repo: ]8;id=788762;https://github.com/DHARPA-Project/kiara_plugin.network_analysis\https://github.com/DHARPA-Project/kiara_plugin.network_analysis]8;;\
#                                   documentation: ]8;id=556263;https://DHARPA-Project.github.io/kiara_plugin.network_analysis/\https://DHARPA-Project.github.io/kiara_plugin.network_analysis/]8;;\
#
#  Operation details
#                      Documentation   Extract the largest connected component from this network data.
#
#                                      This module analyses network data and checks if it contains clusters, and if so, how many. If all
#                                      nodes are connected
#                                      to each other, the input data will be returned as largest component and the 'other_components'
#                                      output will be unset.
#
#                                      Otherwise, the dataset will be split up into nodes of the largest component, and nodes that are not
#                                      part of that.
#                                      Then this module will create 2 new network data items, one for the largest component, and one for
#                                      the other components that excludes
#                                      the nodes and edges that are part of the largest component.
#
#                      Inputs
#                                        field name     type           description                            Required   Default
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        network_data   network_data   The network data to analyze.           yes        -- no default --
#
#
#                      Outputs
#                                        field name             type           description
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        largest_component      network_data   A sub-graph of the largest component of the graph. In case
#                                                                              the graph is a single component, the original input will
#                                                                              be returned.
#                                        other_components       network_data   A sub-graph of the other components of the graph,
#                                                                              excluding the nodes (and edges referencing those nodes)
#                                                                              contained in the largest component.
#                                        number_of_components   integer        The number of components in the graph.
#                                        is_connected           boolean        Whether the graph is connected or not.

# %%
output = kiara.run_job('network_data.extract_largest_component', inputs={'network_data':CKCC})
output
# Out:
# ╭──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                                          │
# │   field                  value                                                                                                           │
# │  ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────      │
# │   is_connected           False                                                                                                           │
# │   largest_component                                                                                                                      │
# │                          Table: edges                                                                                                    │
# │                                                                                                                                          │
# │                            source                                              target                                                    │
# │                           ───────────────────────────────────────────────────────────────────────────────────────────────────            │
# │                            Charas, Moyse, 1619-1698                            Huygens, Christiaan, 1629-1695                            │
# │                            Hartzwich, Peter, fl. 1632                          Groot, Hugo de, 1583-1645                                 │
# │                            Heinsius, Daniel, 1580-1655                         Groot, Hugo de, 1583-1645                                 │
# │                            Heinsius, Daniel, 1580-1655                         Groot, Hugo de, 1583-1645                                 │
# │                            Heinsius, Daniel, 1580-1655                         Groot, Hugo de, 1583-1645                                 │
# │                            Heinsius, Daniel, 1580-1655                         Groot, Hugo de, 1583-1645                                 │
# │                            Heinsius, Daniel, 1580-1655                         Groot, Hugo de, 1583-1645                                 │
# │                            Heinsius, Daniel, 1580-1655                         Groot, Hugo de, 1583-1645                                 │
# │                            Heinsius, Daniel, 1580-1655                         Groot, Hugo de, 1583-1645                                 │
# │                            Heinsius, Daniel, 1580-1655                         Groot, Hugo de, 1583-1645                                 │
# │                            Heinsius, Daniel, 1580-1655                         Groot, Hugo de, 1583-1645                                 │
# │                            Heinsius, Daniel, 1580-1655                         Groot, Hugo de, 1583-1645                                 │
# │                            Heinsius, Daniel, 1580-1655                         Huygens, Constantijn, 1596-1687                           │
# │                            Heinsius, Daniel, 1580-1655                         Huygens, Constantijn, 1596-1687                           │
# │                            Heinsius, Nicolaas, 1620-1681                       Huygens, Christiaan, 1629-1695                            │
# │                            Heinsius, Nicolaas, 1620-1681                       Dati, Carlo Roberto, 1619-1676                            │
# │                            ...                                                 ...                                                       │
# │                            ...                                                 ...                                                       │
# │                            Zeeland, States of                                  Groot, Hugo de, 1583-1645                                 │
# │                            Zeeland, States of                                  Groot, Hugo de, 1583-1645                                 │
# │                            Zeeland, States of                                  Groot, Hugo de, 1583-1645                                 │
# │                            Zeeland, States of                                  Court of Holland, Zeeland and West Friesland,             │
# │                            Zeeland, States of                                  Groot, Hugo de, 1583-1645                                 │
# │                            Zeeland, States of                                  Court of Holland, Zeeland and West Friesland,             │
# │                            Colmar, government of                               Groot, Hugo de, 1583-1645                                 │
# │                            Colmar, government of                               Groot, Hugo de, 1583-1645                                 │
# │                            Colmar, government of                               Groot, Hugo de, 1583-1645                                 │
# │                            Alsace, knighthood of                               Groot, Hugo de, 1583-1645                                 │
# │                            Amsterdam, Committed Councils to the Admiralty of   Groot, Hugo de, 1583-1645                                 │
# │                            Holland, Committed Councils of                      Groot, Hugo de, 1583-1645                                 │
# │                            Dutch East India Company, Zeeland Chamber of the    Groot, Hugo de, 1583-1645                                 │
# │                            Orléans, administration of the German Nation at     Groot, Hugo de, 1583-1645                                 │
# │                            Friesland, Members of the States of                 Unknown                                                   │
# │                            Leiden University                                   Descartes, René, 1596-1650                                │
# │                                                                                                                                          │
# │                          Table: nodes                                                                                                    │
# │                                                                                                                                          │
# │                            id                                                  label                                                     │
# │                           ───────────────────────────────────────────────────────────────────────────────────────────────────────        │
# │                            Heinsius, Nicolaas, 1620-1681                       Heinsius, Nicolaas, 1620-1681                             │
# │                            Vogelaer, Marcus, b.1589                            Vogelaer, Marcus, b.1589                                  │
# │                            Colbert, Jean-Baptiste, 1619-1683                   Colbert, Jean-Baptiste, 1619-1683                         │
# │                            Thorius, Raphael, 1560-1625                         Thorius, Raphael, 1560-1625                               │
# │                            Aubespine, François, 1584-1670                      Aubespine, François, 1584-1670                            │
# │                            Joachimi, Albert, 1560-1654                         Joachimi, Albert, 1560-1654                               │
# │                            Zuerius, Jacob, fl. 1632-1643                       Zuerius, Jacob, fl. 1632-1643                             │
# │                            Vincent, fl. 1636                                   Vincent, fl. 1636                                         │
# │                            Ayala, Ferdinand, fl. 1637-1641                     Ayala, Ferdinand, fl. 1637-1641                           │
# │                            Bouricius, Hector, 1593-1636                        Bouricius, Hector, 1593-1636                              │
# │                            Balzac, Jean Louis Guez, 1597-1654                  Balzac, Jean Louis Guez, 1597-1654                        │
# │                            Brasset, Jean, b.1591                               Brasset, Jean, b.1591                                     │
# │                            Sandilands, James, fl. 1637-1638                    Sandilands, James, fl. 1637-1638                          │
# │                            Hoefnagel, Susanna, 1561-1633                       Hoefnagel, Susanna, 1561-1633                             │
# │                            Gronovius, Johann Frederick, 1611-1671              Gronovius, Johann Frederick, 1611-1671                    │
# │                            Pauw, Adriaan, 1585-1653                            Pauw, Adriaan, 1585-1653                                  │
# │                            ...                                                 ...                                                       │
# │                            ...                                                 ...                                                       │
# │                            Schieland, bailiff and dike warden of, fl. 1644     Schieland, bailiff and dike warden of, fl. 1644           │
# │                            Jan Harmensz, d.1660                                Jan Harmensz, d.1660                                      │
# │                            Oudewater, mayors and governors of                  Oudewater, mayors and governors of                        │
# │                            Drenthe, sheriff and deputies of                    Drenthe, sheriff and deputies of                          │
# │                            Zaltbommel, government of, fl. 1638-1645            Zaltbommel, government of, fl. 1638-1645                  │
# │                            Oudart, Robert, b.1581                              Oudart, Robert, b.1581                                    │
# │                            Pijnacker, Cornelis, 1570-1645                      Pijnacker, Cornelis, 1570-1645                            │
# │                            Sande, Johan van den, 1568-1638                     Sande, Johan van den, 1568-1638                           │
# │                            Suytwijck, Pieter, fl. 1639                         Suytwijck, Pieter, fl. 1639                               │
# │                            Dordrecht, mayors and governors of                  Dordrecht, mayors and governors of                        │
# │                            Zwolle, government of, fl. 1644                     Zwolle, government of, fl. 1644                           │
# │                            Jan Hendriken, d.1660                               Jan Hendriken, d.1660                                     │
# │                            Amsterdam, Committed Councils to the Admiralty of   Amsterdam, Committed Councils to the Admiralty of         │
# │                            Friesland, Members of the States of                 Friesland, Members of the States of                       │
# │                            Dutch East India Company, Zeeland Chamber of the    Dutch East India Company, Zeeland Chamber of the          │
# │                            Alsace, knighthood of                               Alsace, knighthood of                                     │
# │                                                                                                                                          │
# │   number_of_components   8                                                                                                               │
# │   other_components                                                                                                                       │
# │                          Table: edges                                                                                                    │
# │                                                                                                                                          │
# │                            source                                        target                                                          │
# │                           ────────────────────────────────────────────────────────────────────────────────────────────                   │
# │                            Molyneux, Thomas (Sir), 1661-1733             Molyneux, William, 1656-1698                                    │
# │                            Philip IV, King of Spain, 1605-1665           Moncada, Francisco, 1586-1635                                   │
# │                            Ferdinand II, Holy Roman Emperor, 1578-1637   Urban VIII, 1568-1644                                           │
# │                            Duchesne, François, 1616-1693                 Gramont-Chivré, Françoise Marguerite, d.1689                    │
# │                            Gallon, fl. 1678                              Puget, Louis, 1629-1709                                         │
# │                            Berg, Hendrik, 1573-1638                      Schetz, Anthonie, 1564-1641                                     │
# │                            Lorraine, Henri, 1601-1666                    Faret, Nicolas, 1596-1646                                       │
# │                                                                                                                                          │
# │                          Table: nodes                                                                                                    │
# │                                                                                                                                          │
# │                            id                                             label                                                          │
# │                           ─────────────────────────────────────────────────────────────────────────────────────────────                  │
# │                            Philip IV, King of Spain, 1605-1665            Philip IV, King of Spain, 1605-1665                            │
# │                            Molyneux, Thomas (Sir), 1661-1733              Molyneux, Thomas (Sir), 1661-1733                              │
# │                            Moncada, Francisco, 1586-1635                  Moncada, Francisco, 1586-1635                                  │
# │                            Molyneux, William, 1656-1698                   Molyneux, William, 1656-1698                                   │
# │                            Urban VIII, 1568-1644                          Urban VIII, 1568-1644                                          │
# │                            Ferdinand II, Holy Roman Emperor, 1578-1637    Ferdinand II, Holy Roman Emperor, 1578-1637                    │
# │                            Gramont-Chivré, Françoise Marguerite, d.1689   Gramont-Chivré, Françoise Marguerite, d.1689                   │
# │                            Puget, Louis, 1629-1709                        Puget, Louis, 1629-1709                                        │
# │                            Duchesne, François, 1616-1693                  Duchesne, François, 1616-1693                                  │
# │                            Gallon, fl. 1678                               Gallon, fl. 1678                                               │
# │                            Berg, Hendrik, 1573-1638                       Berg, Hendrik, 1573-1638                                       │
# │                            Faret, Nicolas, 1596-1646                      Faret, Nicolas, 1596-1646                                      │
# │                            Schetz, Anthonie, 1564-1641                    Schetz, Anthonie, 1564-1641                                    │
# │                            Lorraine, Henri, 1601-1666                     Lorraine, Henri, 1601-1666                                     │
# │                                                                                                                                          │
# │                                                                                                                                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# For now, let's save our largest component in the variable `network_data` for later - we'll use this for the rest of our experiments rather than the full network, and make sure we're tracing this using <i>kiara</i>.
#
# Let's have a look at the information for this largest component, using our `get_property_data` function again.

# %%
network_data = output['largest_component']

network_data.get_property_data('metadata.graph_properties')
# Out:
#
#   number_of_nodes            1912
#   properties_by_graph_type   {
#                                "graph_type": "directed",
#                                "number_of_edges": 2935
#                              }
#                              {
#                                "graph_type": "undirected",
#                                "number_of_edges": 2325
#                              }
#                              {
#                                "graph_type": "directed-multi",
#                                "number_of_edges": 20022
#                              }
#                              {
#                                "graph_type": "undirected-multi",
#                                "number_of_edges": 20022
#                              }
#   number_of_self_loops       92
#   number_of_parallel_edges   17087

# %% [markdown]
# <h2>Onboarding Data: An Alternative</h2>
#
# So far then, we have created a network object in <i>kiara</i> by importing a csv from a local path.
#
# But what about other formats? Let's pause quickly, and have a look at importing a <b>gml</b> file instead.
#
# Here we will use a different sample dataset, <a href="http://www-personal.umich.edu/~mejn/netdata/">co-appearance network</a> of characters in Victor Hugo's novel <i>Les Miserables</i>, already in gml format.
#
# Let's have a look at the function `onboard.gml_file` and how this will work for us.

# %%
kiara.retrieve_operation_info('onboard.gml_file')
# Out:
#
#  Author(s)
#                      Lena Jaskov         helena.jaskov@uni.lu
#                      Markus Binsteiner   markus@frkl.io
#
#  Context
#                      Tags         dh_tagung_2023
#                      Labels       package: kiara_plugin.dh_tagung_2023
#                      References   source_repo: ]8;id=817054;https://github.com/DHARPA-Project/kiara_plugin.dh_tagung_2023\https://github.com/DHARPA-Project/kiara_plugin.dh_tagung_2023]8;;\
#                                   documentation: ]8;id=639735;https://DHARPA-Project.github.io/kiara_plugin.dh_tagung_2023/\https://DHARPA-Project.github.io/kiara_plugin.dh_tagung_2023/]8;;\
#
#  Operation details
#                      Documentation   This is a preliminary module for onboarding network data from gml files. It will likely be replaced
#                                      by more generic onboarding modules when those are ready.
#
#                                      Based on networkX deserialise GML file method:
#                                      https://networkx.org/documentation/stable/reference/readwrite/generated/networkx.readwrite.gml.read…
#
#                      Inputs
#                                        field name   type     description                                    Required   Default
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        path         string   The path to the local file.                    yes        -- no default --
#                                        label        string   The node attribute that holds the 'label'      no         label
#                                                              information. Set this input to 'id' when
#                                                              there is no 'label' attribute in gml file.
#
#
#                      Outputs
#                                        field name     type           description
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        network_data   network_data   The network/graph data.

# %% [markdown]
# We need a local file path again, and we can go ahead and save this as <b>lesmis</b>.

# %%
lesmis = kiara.run_job('onboard.gml_file', inputs={'path': gml_file_path})
lesmis
# Out:
# ╭──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                                          │
# │   field          value                                                                                                                   │
# │  ────────────────────────────────────────────────────────────                                                                            │
# │   network_data                                                                                                                           │
# │                  Table: edges                                                                                                            │
# │                                                                                                                                          │
# │                    source           target           value                                                                               │
# │                   ─────────────────────────────────────────                                                                              │
# │                    Myriel           Napoleon         1                                                                                   │
# │                    Myriel           MlleBaptistine   8                                                                                   │
# │                    Myriel           MmeMagloire      10                                                                                  │
# │                    Myriel           CountessDeLo     1                                                                                   │
# │                    Myriel           Geborand         1                                                                                   │
# │                    Myriel           Champtercier     1                                                                                   │
# │                    Myriel           Cravatte         1                                                                                   │
# │                    Myriel           Count            2                                                                                   │
# │                    Myriel           OldMan           1                                                                                   │
# │                    Myriel           Valjean          5                                                                                   │
# │                    MlleBaptistine   MmeMagloire      6                                                                                   │
# │                    MlleBaptistine   Valjean          3                                                                                   │
# │                    MmeMagloire      Valjean          3                                                                                   │
# │                    Labarre          Valjean          1                                                                                   │
# │                    Valjean          Marguerite       1                                                                                   │
# │                    Valjean          MmeDeR           1                                                                                   │
# │                    ...              ...              ...                                                                                 │
# │                    ...              ...              ...                                                                                 │
# │                    Bossuet          Grantaire        3                                                                                   │
# │                    Bossuet          MmeHucheloup     1                                                                                   │
# │                    Joly             Grantaire        2                                                                                   │
# │                    Joly             MmeHucheloup     1                                                                                   │
# │                    Grantaire        MmeHucheloup     1                                                                                   │
# │                    Gueulemer        Babet            6                                                                                   │
# │                    Gueulemer        Claquesous       4                                                                                   │
# │                    Gueulemer        Montparnasse     2                                                                                   │
# │                    Gueulemer        Brujon           3                                                                                   │
# │                    Babet            Claquesous       4                                                                                   │
# │                    Babet            Montparnasse     2                                                                                   │
# │                    Babet            Brujon           3                                                                                   │
# │                    Claquesous       Montparnasse     2                                                                                   │
# │                    Claquesous       Brujon           1                                                                                   │
# │                    Montparnasse     Brujon           1                                                                                   │
# │                    Child1           Child2           3                                                                                   │
# │                                                                                                                                          │
# │                  Table: nodes                                                                                                            │
# │                                                                                                                                          │
# │                    id               label                                                                                                │
# │                   ─────────────────────────────────                                                                                      │
# │                    Myriel           Myriel                                                                                               │
# │                    Napoleon         Napoleon                                                                                             │
# │                    MlleBaptistine   MlleBaptistine                                                                                       │
# │                    MmeMagloire      MmeMagloire                                                                                          │
# │                    CountessDeLo     CountessDeLo                                                                                         │
# │                    Geborand         Geborand                                                                                             │
# │                    Champtercier     Champtercier                                                                                         │
# │                    Cravatte         Cravatte                                                                                             │
# │                    Count            Count                                                                                                │
# │                    OldMan           OldMan                                                                                               │
# │                    Labarre          Labarre                                                                                              │
# │                    Valjean          Valjean                                                                                              │
# │                    Marguerite       Marguerite                                                                                           │
# │                    MmeDeR           MmeDeR                                                                                               │
# │                    Isabeau          Isabeau                                                                                              │
# │                    Gervais          Gervais                                                                                              │
# │                    ...              ...                                                                                                  │
# │                    ...              ...                                                                                                  │
# │                    Feuilly          Feuilly                                                                                              │
# │                    Courfeyrac       Courfeyrac                                                                                           │
# │                    Bahorel          Bahorel                                                                                              │
# │                    Bossuet          Bossuet                                                                                              │
# │                    Joly             Joly                                                                                                 │
# │                    Grantaire        Grantaire                                                                                            │
# │                    MotherPlutarch   MotherPlutarch                                                                                       │
# │                    Gueulemer        Gueulemer                                                                                            │
# │                    Babet            Babet                                                                                                │
# │                    Claquesous       Claquesous                                                                                           │
# │                    Montparnasse     Montparnasse                                                                                         │
# │                    Toussaint        Toussaint                                                                                            │
# │                    Child1           Child1                                                                                               │
# │                    Child2           Child2                                                                                               │
# │                    Brujon           Brujon                                                                                               │
# │                    MmeHucheloup     MmeHucheloup                                                                                         │
# │                                                                                                                                          │
# │                                                                                                                                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# As we can see, this module not only imports the gml file into <i>kiara</i> but automatically converts it into a <i>kiara</i> network object for us. Great!
#
# Here we can see that the edge table has a 'value' column to indicate edges weights that has also been automatically included with the gml data.
#
# We'll leave this <i>Les Miserables</i> network for now, but it's useful to see this other option for importing data for networks. If you want to experiment with this dataset later, feel free to come back to it!

# %% [markdown]
# <h2>Network Analysis: Statistical Measures</h2>
#
# Ok, let's head back to our correspSearch largest component dataset, stored in the variable <b>network_data</b>. We've already had a look at some graph wide measures, so let's start looking at some node specific measurements.
#
# <b>Degree</b>
# <br>Let's start with degree, using `create.degree_rank_list`. This module allows us to calculate degree as both <b>undirected</b> and <b>weighted</b>. In this epistolary network, <b>undirected degree</b> counts the number of individual correspondents each person has, whereas <b>weighted degree</b> counts the total number of incoming and outgoing letters for each actor in the network.
#
# Let's use our `retrieve_operation_info` function to have a look at what we need to calculate these degrees.

# %%
kiara.retrieve_operation_info('create.degree_rank_list')
# Out:
#
#  Author(s)
#                      Caitlin Burge       caitlin.burge@uni.lu
#                      Markus Binsteiner   markus@frkl.io
#
#  Context
#                      Tags         dh_tagung_2023
#                      Labels       package: kiara_plugin.dh_tagung_2023
#                      References   source_repo: ]8;id=538998;https://github.com/DHARPA-Project/kiara_plugin.dh_tagung_2023\https://github.com/DHARPA-Project/kiara_plugin.dh_tagung_2023]8;;\
#                                   documentation: ]8;id=622440;https://DHARPA-Project.github.io/kiara_plugin.dh_tagung_2023/\https://DHARPA-Project.github.io/kiara_plugin.dh_tagung_2023/]8;;\
#
#  Operation details
#                      Documentation   Creates an ordered table with the rank and raw score for degree and weighted degree.
#
#                                      Unweighted degree centrality uses an undirected graph and measures the number of independent
#                                      connections each node has.
#                                      Weighted degree centrality uses a directed graph and measures the total number of connections or
#                                      weight attached to a node.
#
#                                      Uses networkx degree.
#                                      https://networkx.org/documentation/stable/reference/generated/networkx.classes.function.degree.html
#
#                      Inputs
#                                        field name           type           description                      Required   Default
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        network_data         network_data   The network graph being          yes        -- no default --
#                                                                            queried.
#                                        weighted_degree      boolean        Boolean to indicate whether to   no         True
#                                                                            calculate weighted degree or
#                                                                            not. Conditions for
#                                                                            calculation can be set in
#                                                                            'weight_column_name'.
#                                        weight_column_name   string         The name of the column in the    no
#                                                                            edge table containing data for
#                                                                            the 'weight' or 'strength' of
#                                                                            an edge. If there is a column
#                                                                            already named 'weight', this
#                                                                            will be automatically
#                                                                            selected. If otherwise left
#                                                                            empty, weighted degree is
#                                                                            calculated by aggregrating
#                                                                            parallel edges where edge
#                                                                            weight is assigned a weight of
#                                                                            1.
#
#
#                      Outputs
#                                        field name           type           description
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        network_result       table          A table showing the rank and raw score for degree
#                                                                            centrality.
#                                        centrality_network   network_data   Updated network data with degree ranking assigned as a node
#                                                                            attribute.

# %% [markdown]
# So we've already computed the largest component to use as the `network_data` input, and we want to calculate the weighted degree meaures, so we'll leave the default as 'True'. Unlike the <i>Les Miserables</i> network, we don't have a pre-existing weight value for the edges, but we do know that there are parallell edges from multiple letters between correspondents, so we'll allow the module to aggregate the edges and set this as a weight.
#
# In creating this module, assumptions have already been made that we are working with both a single node type and a single edge type network. Again, a lot of the parameters have been set based on what we already know about the dataset, but we also need to acknowledge this as an active decision that has been 'pre-made' as part of the research process.
#
# The inputs for `create.degree_rank_list` are prompting us to reflect on the decisions we are making as we are going along, and think about how our data fits into these kind of measurements, but by doing it in <i>kiara</i>, these inputs also allows us to <i>track</i> these decisions, as we will see more of later.
#
# Let's give it a go then.

# %%
output = kiara.run_job('create.degree_rank_list', inputs={'network_data':network_data})
output
# Out:
# ╭──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                                          │
# │   field                value                                                                                                             │
# │  ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────  │
# │   centrality_network                                                                                                                     │
# │                        Table: edges                                                                                                      │
# │                                                                                                                                          │
# │                          source                                           target                                           weight        │
# │                         ──────────────────────────────────────────────────────────────────────────────────────────────────────────       │
# │                          Heinsius, Nicolaas, 1620-1681                    Huygens, Christiaan, 1629-1695                   12            │
# │                          Heinsius, Nicolaas, 1620-1681                    Dati, Carlo Roberto, 1619-1676                   6             │
# │                          Heinsius, Nicolaas, 1620-1681                    Boulliau, Ismaël, 1605-1694                      1             │
# │                          Heinsius, Nicolaas, 1620-1681                    Gronovius, Johann Frederick, 1611-1671           1             │
# │                          Heinsius, Nicolaas, 1620-1681                    Chapelain, Jean, 1595-1674                       2             │
# │                          Heinsius, Nicolaas, 1620-1681                    Lubieniecki, Stanisław, 1623-1675                1             │
# │                          Heinsius, Nicolaas, 1620-1681                    Huygens, Constantijn, 1596-1687                  12            │
# │                          Vogelaer, Marcus, b.1589                         Huygens, Constantijn, 1596-1687                  1             │
# │                          Colbert, Jean-Baptiste, 1619-1683                Huygens, Constantijn, 1596-1687                  4             │
# │                          Colbert, Jean-Baptiste, 1619-1683                Huygens, Christiaan, 1629-1695                   2             │
# │                          Colbert, Jean-Baptiste, 1619-1683                Dulaurens, François, fl. 1667-1669               2             │
# │                          Colbert, Jean-Baptiste, 1619-1683                Voye, 1619-1684                                  1             │
# │                          Thorius, Raphael, 1560-1625                      Huygens, Constantijn, 1596-1687                  1             │
# │                          Thorius, Raphael, 1560-1625                      Groot, Hugo de, 1583-1645                        1             │
# │                          Aubespine, François, 1584-1670                   Huygens, Constantijn, 1596-1687                  4             │
# │                          Joachimi, Albert, 1560-1654                      Huygens, Constantijn, 1596-1687                  1             │
# │                          ...                                              ...                                              ...           │
# │                          ...                                              ...                                              ...           │
# │                          Court of Holland, Zeeland and West Friesland,    Huygens, Pieter, fl. 1612                        1             │
# │                          Court of Holland, Zeeland and West Friesland,    Zeeland, States of                               2             │
# │                          Reigersberch, Maria, 1589-1653                   Horn, Gustav Karlsson af Björneborg, 1592-1657   1             │
# │                          Courcelles, Étienne de, 1586-1659                Cupus, Petrus, 1580-1646                         1             │
# │                          Banér, Johann, 1596-1641                         Schörlings, Balthasar, d.1638                    1             │
# │                          Horn, Gustav Karlsson af Björneborg, 1592-1657   Mockhel, Friedrich Richard, d.1646               1             │
# │                          Mockhel, Friedrich Richard, d.1646               Budes, Jean Baptiste, 1602-1643                  1             │
# │                          Goes, Willem, 1613-1688                          Magliabechi, Antonio, 1633-1714                  1             │
# │                          Mencke, Otto, 1644-1707                          Bernoulli, Jacob (I), 1655-1705                  1             │
# │                          Columbus, Johan, 1640-1684                       Bilberg, Johann, 1650-1717                       1             │
# │                          Columbus, Johan, 1640-1684                       Spole, Andreas, 1630-1699                        1             │
# │                          Bruynestein, Jan, 1642-1686                      Liebergen, Diederik, d.1705                      1             │
# │                          Bryas, Charles, 1625-1686                        Campani, Giuseppe, 1635-1715                     1             │
# │                          Boccone, Paolo Silvio, 1633-1704                 Seyen, Arnoldus, 1640-1678                       2             │
# │                          Voogt, Klaas Jansz, d.1696                       Dam, Albert Jansz. van, 1646-1720                1             │
# │                          Zalm, Klaas Dirksz, fl. 1677                     Dam, Albert Jansz. van, 1646-1720                2             │
# │                                                                                                                                          │
# │                        Table: nodes                                                                                                      │
# │                                                                                                                                          │
# │                          Degree Score   Weighted Degree Score   label                               id                                   │
# │                         ─────────────────────────────────────────────────────────────────────────────────────────────────────────────    │
# │                          7              67                      Heinsius, Nicolaas, 1620-1681       Heinsius, Nicolaas, 1620-1681        │
# │                          1              2                       Vogelaer, Marcus, b.1589            Vogelaer, Marcus, b.1589             │
# │                          4              25                      Colbert, Jean-Baptiste, 1619-1683   Colbert, Jean-Baptiste, 1619-168     │
# │                          2              5                       Thorius, Raphael, 1560-1625         Thorius, Raphael, 1560-1625          │
# │                          1              4                       Aubespine, François, 1584-1670      Aubespine, François, 1584-1670       │
# │                          1              2                       Joachimi, Albert, 1560-1654         Joachimi, Albert, 1560-1654          │
# │                          1              4                       Zuerius, Jacob, fl. 1632-1643       Zuerius, Jacob, fl. 1632-1643        │
# │                          1              2                       Vincent, fl. 1636                   Vincent, fl. 1636                    │
# │                          1              3                       Ayala, Ferdinand, fl. 1637-1641     Ayala, Ferdinand, fl. 1637-1641      │
# │                          2              4                       Bouricius, Hector, 1593-1636        Bouricius, Hector, 1593-1636         │
# │                          2              20                      Balzac, Jean Louis Guez, 1597-165   Balzac, Jean Louis Guez, 1597-16     │
# │                          2              21                      Brasset, Jean, b.1591               Brasset, Jean, b.1591                │
# │                          1              2                       Sandilands, James, fl. 1637-1638    Sandilands, James, fl. 1637-1638     │
# │                          1              21                      Hoefnagel, Susanna, 1561-1633       Hoefnagel, Susanna, 1561-1633        │
# │                          3              30                      Gronovius, Johann Frederick, 1611   Gronovius, Johann Frederick, 161     │
# │                          1              8                       Pauw, Adriaan, 1585-1653            Pauw, Adriaan, 1585-1653             │
# │                          ...            ...                     ...                                 ...                                  │
# │                          ...            ...                     ...                                 ...                                  │
# │                          1              1                       Schieland, bailiff and dike warde   Schieland, bailiff and dike ward     │
# │                          1              1                       Jan Harmensz, d.1660                Jan Harmensz, d.1660                 │
# │                          1              1                       Oudewater, mayors and governors o   Oudewater, mayors and governors      │
# │                          1              3                       Drenthe, sheriff and deputies of    Drenthe, sheriff and deputies of     │
# │                          1              2                       Zaltbommel, government of, fl. 16   Zaltbommel, government of, fl. 1     │
# │                          1              1                       Oudart, Robert, b.1581              Oudart, Robert, b.1581               │
# │                          1              5                       Pijnacker, Cornelis, 1570-1645      Pijnacker, Cornelis, 1570-1645       │
# │                          1              2                       Sande, Johan van den, 1568-1638     Sande, Johan van den, 1568-1638      │
# │                          1              1                       Suytwijck, Pieter, fl. 1639         Suytwijck, Pieter, fl. 1639          │
# │                          1              1                       Dordrecht, mayors and governors o   Dordrecht, mayors and governors      │
# │                          1              1                       Zwolle, government of, fl. 1644     Zwolle, government of, fl. 1644      │
# │                          1              1                       Jan Hendriken, d.1660               Jan Hendriken, d.1660                │
# │                          1              1                       Amsterdam, Committed Councils to    Amsterdam, Committed Councils to     │
# │                          1              1                       Friesland, Members of the States    Friesland, Members of the States     │
# │                          1              1                       Dutch East India Company, Zeeland   Dutch East India Company, Zeelan     │
# │                          1              1                       Alsace, knighthood of               Alsace, knighthood of                │
# │                                                                                                                                          │
# │   network_result                                                                                                                         │
# │                          Rank   Node                                                Degree   Weighted Degree                             │
# │                         ─────────────────────────────────────────────────────────────────────────────────────                            │
# │                          1      Huygens, Constantijn, 1596-1687                     1145     7497                                        │
# │                          2      Groot, Hugo de, 1583-1645                           390      7765                                        │
# │                          3      Huygens, Christiaan, 1629-1695                      259      2698                                        │
# │                          4      Barlaeus, Caspar, 1584-1648                         116      738                                         │
# │                          5      Descartes, René, 1596-1650                          92       749                                         │
# │                          6      Unknown                                             56       457                                         │
# │                          7      Leeuwenhoek, Antoni van, 1632-1723                  43       290                                         │
# │                          8      Nierop, Dirck Rembrantsz van, 1610-1682             30       84                                          │
# │                          9      Christina, Queen of Sweden, 1626-1689               20       169                                         │
# │                          10     Oldenburg, Henry, 1619-1677                         17       213                                         │
# │                          11     Swammerdam, Jan, 1637-1680                          16       168                                         │
# │                          12     Oxenstierna, Axel (Count), 1583-1654                15       658                                         │
# │                          13     Staten-Generaal der Nederlanden                     10       24                                          │
# │                          13     Schooten, Frans van, 1615-1660                      10       143                                         │
# │                          13     Groot, Willem de, 1597-1662                         10       1153                                        │
# │                          16     Thévenot, Melchisédech, 1620-1692                   9        97                                          │
# │                          ...    ...                                                 ...      ...                                         │
# │                          ...    ...                                                 ...      ...                                         │
# │                          306    Schieland, bailiff and dike warden of, fl. 1644     1        1                                           │
# │                          306    Jan Harmensz, d.1660                                1        1                                           │
# │                          306    Oudewater, mayors and governors of                  1        1                                           │
# │                          306    Drenthe, sheriff and deputies of                    1        3                                           │
# │                          306    Zaltbommel, government of, fl. 1638-1645            1        2                                           │
# │                          306    Oudart, Robert, b.1581                              1        1                                           │
# │                          306    Pijnacker, Cornelis, 1570-1645                      1        5                                           │
# │                          306    Sande, Johan van den, 1568-1638                     1        2                                           │
# │                          306    Suytwijck, Pieter, fl. 1639                         1        1                                           │
# │                          306    Dordrecht, mayors and governors of                  1        1                                           │
# │                          306    Zwolle, government of, fl. 1644                     1        1                                           │
# │                          306    Jan Hendriken, d.1660                               1        1                                           │
# │                          306    Amsterdam, Committed Councils to the Admiralty of   1        1                                           │
# │                          306    Friesland, Members of the States of                 1        1                                           │
# │                          306    Dutch East India Company, Zeeland Chamber of the    1        1                                           │
# │                          306    Alsace, knighthood of                               1        1                                           │
# │                                                                                                                                          │
# │                                                                                                                                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# Great, this function gives us a table with the undirected degree and weighted degree for each member of this network, ranking them by undirected degree.
#
# In doing so, it's done two extra things for us. Seeing as we allowed the function to calculate parallel edges as edge weight, it's now saved the weight as an edge attribute that we can carry forward into our next measurements. It's also assigned the two degree scores as node attributes in our network, which means we can also keep these in further centrality measurements, allowing us to accumulate all the different scores rather than re-writing over them each time.
#
# <b>Betweenness</b>
# <br>Let's have a look at a different centrality measure now - use `retrieve.operation.info` again to see what we need to calculate betweenness for the nodes in our network.

# %%
kiara.retrieve_operation_info('create.betweenness_rank_list')
# Out:
#
#  Author(s)
#                      Caitlin Burge       caitlin.burge@uni.lu
#                      Markus Binsteiner   markus@frkl.io
#
#  Context
#                      Tags         dh_tagung_2023
#                      Labels       package: kiara_plugin.dh_tagung_2023
#                      References   source_repo: ]8;id=833623;https://github.com/DHARPA-Project/kiara_plugin.dh_tagung_2023\https://github.com/DHARPA-Project/kiara_plugin.dh_tagung_2023]8;;\
#                                   documentation: ]8;id=10272;https://DHARPA-Project.github.io/kiara_plugin.dh_tagung_2023/\https://DHARPA-Project.github.io/kiara_plugin.dh_tagung_2023/]8;;\
#
#  Operation details
#                      Documentation   Creates an ordered table with the rank and raw score for betweenness centrality.
#
#                                      Betweenness centrality measures the percentage of all shortest paths that a node appears on,
#                                      therefore measuring the likeliness that a node may act as a connector or 'intermediary'.
#
#                                      Uses a directed graph and networkx.betweenness_centrality()
#                                      https://networkx.org/documentation/stable/reference/algorithms/generated/networkx.algorithms.centra…
#
#                      Inputs
#                                        field name             type           description                    Required   Default
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        network_data           network_data   The network graph being        yes        -- no default --
#                                                                              queried.
#                                        weighted_betweenness   boolean        Boolean to indicate whether    no         True
#                                                                              to calculate weighted
#                                                                              betweenness as well as
#                                                                              unweighted betweenness.
#                                        weight_column_name     string         The name of the column in      no
#                                                                              the edge table containing
#                                                                              data for the 'weight' of an
#                                                                              edge. If there is a column
#                                                                              already named 'weight', this
#                                                                              will be automatically
#                                                                              selected. If otherwise left
#                                                                              empty, weight is calculated
#                                                                              by aggregrating parallel
#                                                                              edges where edge weight is
#                                                                              assigned a weight of 1.
#                                        weight_meaning         boolean        How the weights given should   no         True
#                                                                              be interpreted. If 'True',
#                                                                              weight will be defined
#                                                                              positively as 'strength',
#                                                                              and these edges will be
#                                                                              prioritised in shortest path
#                                                                              calculations. If 'False',
#                                                                              weight will be defined
#                                                                              negatively as 'cost' or
#                                                                              'distance', and these edges
#                                                                              will be avoided in shortest
#                                                                              path calculations.
#
#
#                      Outputs
#                                        field name           type           description
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        network_result       table          A table showing the rank and raw score for betweenness
#                                                                            centrality.
#                                        centrality_network   network_data   Updated network data with betweenness ranking assigned as a
#                                                                            node attribute.

# %% [markdown]
# This module allows us to calculate both unweighted and weighted betweenness, so we'll go ahead and do both of those. Again, we can select a column that holds the edge weight if, like in our <i>Les Miserables</i> network, it it already exists or has a different label. As we just used the degree module to calculate edge weight using the parallel edges, we can leave this and it will automatically select the 'weight' column we just created.
#
# This module also asks us to define how we want our weights to be interpreted - is the weight 'positive', indicating strong relationships, or is it 'negative', acting as a distance or time needed for these edges? Whilst this is often automated in network measures, <i>kiara</i> prompts us to think more carefully about our data and our network, and again gets us to trace the decisions we as researchers are making about our analysis.
#
# As we're dealing with epistolary data, we'll leave this input as 'True', as the weight indicates strength. At this stage, the module is also set to calculate both unweighted and weighted betweenness using the network as a directed graph. Though this is another 'pre-made' decision for this notebook and the dataset in use, it's important to acknowledge this and be as transparent about these kind of choices as the ones actively documented by user input.
#
# Let's give it a go then. We want to use the network we just created using the degree ranking module, so let's save that and use it in our inputs.

# %%
network_data = output['centrality_network']

output = kiara.run_job('create.betweenness_rank_list', inputs={'network_data':network_data})

output
# Out:
# ╭──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                                          │
# │   field                value                                                                                                             │
# │  ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────  │
# │   centrality_network                                                                                                                     │
# │                        Table: edges                                                                                                      │
# │                                                                                                                                          │
# │                          source                                           target                                           weight        │
# │                         ──────────────────────────────────────────────────────────────────────────────────────────────────────────       │
# │                          Heinsius, Nicolaas, 1620-1681                    Huygens, Christiaan, 1629-1695                   12            │
# │                          Heinsius, Nicolaas, 1620-1681                    Dati, Carlo Roberto, 1619-1676                   6             │
# │                          Heinsius, Nicolaas, 1620-1681                    Boulliau, Ismaël, 1605-1694                      1             │
# │                          Heinsius, Nicolaas, 1620-1681                    Gronovius, Johann Frederick, 1611-1671           1             │
# │                          Heinsius, Nicolaas, 1620-1681                    Chapelain, Jean, 1595-1674                       2             │
# │                          Heinsius, Nicolaas, 1620-1681                    Lubieniecki, Stanisław, 1623-1675                1             │
# │                          Heinsius, Nicolaas, 1620-1681                    Huygens, Constantijn, 1596-1687                  12            │
# │                          Vogelaer, Marcus, b.1589                         Huygens, Constantijn, 1596-1687                  1             │
# │                          Colbert, Jean-Baptiste, 1619-1683                Huygens, Constantijn, 1596-1687                  4             │
# │                          Colbert, Jean-Baptiste, 1619-1683                Huygens, Christiaan, 1629-1695                   2             │
# │                          Colbert, Jean-Baptiste, 1619-1683                Dulaurens, François, fl. 1667-1669               2             │
# │                          Colbert, Jean-Baptiste, 1619-1683                Voye, 1619-1684                                  1             │
# │                          Thorius, Raphael, 1560-1625                      Huygens, Constantijn, 1596-1687                  1             │
# │                          Thorius, Raphael, 1560-1625                      Groot, Hugo de, 1583-1645                        1             │
# │                          Aubespine, François, 1584-1670                   Huygens, Constantijn, 1596-1687                  4             │
# │                          Joachimi, Albert, 1560-1654                      Huygens, Constantijn, 1596-1687                  1             │
# │                          ...                                              ...                                              ...           │
# │                          ...                                              ...                                              ...           │
# │                          Court of Holland, Zeeland and West Friesland,    Huygens, Pieter, fl. 1612                        1             │
# │                          Court of Holland, Zeeland and West Friesland,    Zeeland, States of                               2             │
# │                          Reigersberch, Maria, 1589-1653                   Horn, Gustav Karlsson af Björneborg, 1592-1657   1             │
# │                          Courcelles, Étienne de, 1586-1659                Cupus, Petrus, 1580-1646                         1             │
# │                          Banér, Johann, 1596-1641                         Schörlings, Balthasar, d.1638                    1             │
# │                          Horn, Gustav Karlsson af Björneborg, 1592-1657   Mockhel, Friedrich Richard, d.1646               1             │
# │                          Mockhel, Friedrich Richard, d.1646               Budes, Jean Baptiste, 1602-1643                  1             │
# │                          Goes, Willem, 1613-1688                          Magliabechi, Antonio, 1633-1714                  1             │
# │                          Mencke, Otto, 1644-1707                          Bernoulli, Jacob (I), 1655-1705                  1             │
# │                          Columbus, Johan, 1640-1684                       Bilberg, Johann, 1650-1717                       1             │
# │                          Columbus, Johan, 1640-1684                       Spole, Andreas, 1630-1699                        1             │
# │                          Bruynestein, Jan, 1642-1686                      Liebergen, Diederik, d.1705                      1             │
# │                          Bryas, Charles, 1625-1686                        Campani, Giuseppe, 1635-1715                     1             │
# │                          Boccone, Paolo Silvio, 1633-1704                 Seyen, Arnoldus, 1640-1678                       2             │
# │                          Voogt, Klaas Jansz, d.1696                       Dam, Albert Jansz. van, 1646-1720                1             │
# │                          Zalm, Klaas Dirksz, fl. 1677                     Dam, Albert Jansz. van, 1646-1720                2             │
# │                                                                                                                                          │
# │                        Table: nodes                                                                                                      │
# │                                                                                                                                          │
# │                          Degree Score   Weighted Between   Weighted Degree    Betweenness Scor   label              id                   │
# │                         ─────────────────────────────────────────────────────────────────────────────────────────────────────────────    │
# │                          7              0.0                67                 0.0                Heinsius, Nicola   Heinsius, Nicola     │
# │                          1              0.0                2                  0.0                Vogelaer, Marcus   Vogelaer, Marcus     │
# │                          4              0.0                25                 0.0                Colbert, Jean-Ba   Colbert, Jean-Ba     │
# │                          2              0.0                5                  0.0                Thorius, Raphael   Thorius, Raphael     │
# │                          1              0.0                4                  0.0                Aubespine, Franç   Aubespine, Franç     │
# │                          1              0.0                2                  0.0                Joachimi, Albert   Joachimi, Albert     │
# │                          1              0.0                4                  0.0                Zuerius, Jacob,    Zuerius, Jacob,      │
# │                          1              0.0                2                  0.0                Vincent, fl. 163   Vincent, fl. 163     │
# │                          1              0.0                3                  0.0                Ayala, Ferdinand   Ayala, Ferdinand     │
# │                          2              0.0                4                  0.0                Bouricius, Hecto   Bouricius, Hecto     │
# │                          2              0.0                20                 0.0                Balzac, Jean Lou   Balzac, Jean Lou     │
# │                          2              0.0                21                 0.0                Brasset, Jean, b   Brasset, Jean, b     │
# │                          1              0.0                2                  0.0                Sandilands, Jame   Sandilands, Jame     │
# │                          1              0.0                21                 0.0                Hoefnagel, Susan   Hoefnagel, Susan     │
# │                          3              0.00043559241390   30                 4.27117966384982   Gronovius, Johan   Gronovius, Johan     │
# │                          1              0.0                8                  0.0                Pauw, Adriaan, 1   Pauw, Adriaan, 1     │
# │                          ...            ...                ...                ...                ...                ...                  │
# │                          ...            ...                ...                ...                ...                ...                  │
# │                          1              0.0                1                  0.0                Schieland, baili   Schieland, baili     │
# │                          1              0.0                1                  0.0                Jan Harmensz, d.   Jan Harmensz, d.     │
# │                          1              0.0                1                  0.0                Oudewater, mayor   Oudewater, mayor     │
# │                          1              0.0                3                  0.0                Drenthe, sheriff   Drenthe, sheriff     │
# │                          1              0.0                2                  0.0                Zaltbommel, gove   Zaltbommel, gove     │
# │                          1              0.0                1                  0.0                Oudart, Robert,    Oudart, Robert,      │
# │                          1              0.0                5                  0.0                Pijnacker, Corne   Pijnacker, Corne     │
# │                          1              0.0                2                  0.0                Sande, Johan van   Sande, Johan van     │
# │                          1              0.0                1                  0.0                Suytwijck, Piete   Suytwijck, Piete     │
# │                          1              0.0                1                  0.0                Dordrecht, mayor   Dordrecht, mayor     │
# │                          1              0.0                1                  0.0                Zwolle, governme   Zwolle, governme     │
# │                          1              0.0                1                  0.0                Jan Hendriken, d   Jan Hendriken, d     │
# │                          1              0.0                1                  0.0                Amsterdam, Commi   Amsterdam, Commi     │
# │                          1              0.0                1                  0.0                Friesland, Membe   Friesland, Membe     │
# │                          1              0.0                1                  0.0                Dutch East India   Dutch East India     │
# │                          1              0.0                1                  0.0                Alsace, knightho   Alsace, knightho     │
# │                                                                                                                                          │
# │   network_result                                                                                                                         │
# │                          Rank   Node                                                Score                    Weighted Betweenness        │
# │                         ────────────────────────────────────────────────────────────────────────────────────────────────────────────     │
# │                          1      Huygens, Constantijn, 1596-1687                     0.010969525363691411     0.011344900424930344        │
# │                          2      Groot, Hugo de, 1583-1645                           0.005327086336275351     0.005213045078415311        │
# │                          3      Huygens, Christiaan, 1629-1695                      0.0030295682480744987    0.0029767954973639347       │
# │                          4      Barlaeus, Caspar, 1584-1648                         0.0016136499703120067    0.0017360683030092157       │
# │                          5      Descartes, René, 1596-1650                          0.0007141639490181001    0.000733376986181773        │
# │                          6      Leeuwenhoek, Antoni van, 1632-1723                  0.00038125466322923323   0.00040913129918365536      │
# │                          7      Nierop, Dirck Rembrantsz van, 1610-1682             0.00028515903609396505   0.00030369779808822443      │
# │                          8      Christina, Queen of Sweden, 1626-1689               0.00019577660885492916   0.00021474827009606366      │
# │                          9      Unknown                                             0.00017512325264221835   0.0001902734513056129       │
# │                          10     Oldenburg, Henry, 1619-1677                         0.00016486256202037804   0.00023260210245999328      │
# │                          11     Swammerdam, Jan, 1637-1680                          0.00016383516757488336   0.00016383516757488336      │
# │                          12     Staten-Generaal der Nederlanden                     0.00010849285344423715   0.00011853848802240724      │
# │                          13     Oxenstierna, Axel (Count), 1583-1654                8.577335214796482e-05    0.00014520508162991336      │
# │                          14     Thévenot, Melchisédech, 1620-1692                   7.552490723769708e-05    0.00022527335541546465      │
# │                          15     Schooten, Frans van, 1615-1660                      4.9634567211231386e-05   5.684915931737174e-05       │
# │                          16     Beeckman, Isaac, 1588-1637                          4.835603190128247e-05    4.931493338374416e-05       │
# │                          ...    ...                                                 ...                      ...                         │
# │                          ...    ...                                                 ...                      ...                         │
# │                          80     Schieland, bailiff and dike warden of, fl. 1644     0.0                      0.0                         │
# │                          80     Jan Harmensz, d.1660                                0.0                      0.0                         │
# │                          80     Oudewater, mayors and governors of                  0.0                      0.0                         │
# │                          80     Drenthe, sheriff and deputies of                    0.0                      0.0                         │
# │                          80     Zaltbommel, government of, fl. 1638-1645            0.0                      0.0                         │
# │                          80     Oudart, Robert, b.1581                              0.0                      0.0                         │
# │                          80     Pijnacker, Cornelis, 1570-1645                      0.0                      0.0                         │
# │                          80     Sande, Johan van den, 1568-1638                     0.0                      0.0                         │
# │                          80     Suytwijck, Pieter, fl. 1639                         0.0                      0.0                         │
# │                          80     Dordrecht, mayors and governors of                  0.0                      0.0                         │
# │                          80     Zwolle, government of, fl. 1644                     0.0                      0.0                         │
# │                          80     Jan Hendriken, d.1660                               0.0                      0.0                         │
# │                          80     Amsterdam, Committed Councils to the Admiralty of   0.0                      0.0                         │
# │                          80     Friesland, Members of the States of                 0.0                      0.0                         │
# │                          80     Dutch East India Company, Zeeland Chamber of the    0.0                      0.0                         │
# │                          80     Alsace, knighthood of                               0.0                      0.0                         │
# │                                                                                                                                          │
# │                                                                                                                                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# Just like the degree module, it's returned a table with the two betweenness scores, ranked by unweighted, and also assigned these as node attributes that we can carry forward into more measurements. Let's look at one more centrality here in this notebook.
#
# <b>Eigenvector</b>
# <br><i>kiara</i> also holds a module to measure eigenvector centrality, so let's look again at what that needs.

# %%
kiara.retrieve_operation_info('create.eigenvector_rank_list')
# Out:
#
#  Author(s)
#                      Caitlin Burge       caitlin.burge@uni.lu
#                      Markus Binsteiner   markus@frkl.io
#
#  Context
#                      Tags         dh_tagung_2023
#                      Labels       package: kiara_plugin.dh_tagung_2023
#                      References   source_repo: ]8;id=818894;https://github.com/DHARPA-Project/kiara_plugin.dh_tagung_2023\https://github.com/DHARPA-Project/kiara_plugin.dh_tagung_2023]8;;\
#                                   documentation: ]8;id=234062;https://DHARPA-Project.github.io/kiara_plugin.dh_tagung_2023/\https://DHARPA-Project.github.io/kiara_plugin.dh_tagung_2023/]8;;\
#
#  Operation details
#                      Documentation   Creates an ordered table with the rank and raw score for betweenness centrality.
#
#                                      Eigenvector centrality measures the extent to which a node is connected to other nodes of importance
#                                      or influence.
#
#                                      Uses an undirected graph networkx.eigenvector_centrality()
#                                      https://networkx.org/documentation/stable/reference/algorithms/generated/networkx.algorithms.centra…
#
#                      Inputs
#                                        field name             type           description                    Required   Default
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        network_data           network_data   The network graph being        yes        -- no default --
#                                                                              queried.
#                                        iterations             integer        -- n/a --                      no         1000
#                                        weighted_eigenvector   boolean        Boolean to indicate whether    no         True
#                                                                              to calculate weighted
#                                                                              eigenvector as well as
#                                                                              unweighted eigenvector.
#                                        weight_column_name     string         The name of the column in      no
#                                                                              the edge table containing
#                                                                              data for the 'weight' of an
#                                                                              edge. If there is a column
#                                                                              already named 'weight', this
#                                                                              will be automatically
#                                                                              selected. If otherwise left
#                                                                              empty, weight is calculated
#                                                                              by aggregrating parallel
#                                                                              edges where edge weight is
#                                                                              assigned a weight of 1.
#                                        weight_meaning         boolean        How the weights given should   no         True
#                                                                              be interpreted. If 'True',
#                                                                              weight will be defined
#                                                                              positively as 'strength',
#                                                                              and these edges will be
#                                                                              prioritised in shortest path
#                                                                              calculations. If 'False',
#                                                                              weight will be defined
#                                                                              negatively as 'cost' or
#                                                                              'distance', and these edges
#                                                                              will be avoided in shortest
#                                                                              path calculations.
#
#
#                      Outputs
#                                        field name           type           description
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        network_result       table          A table showing the rank and raw score for eigenvector
#                                                                            centrality.
#                                        centrality_network   network_data   Updated network data with eigenvector ranking assigned as a
#                                                                            node attribute.

# %% [markdown]
# This module is set up similary to the betweenness measure, and again we can define the column with the weight information if we need to, and how to interpret these weights. If you have a larger dataset, you can also change the iterations for the measurement. For the moment we'll leave the parameters as they are, and again use our updated network with the degree and betweenness scores attached.

# %%
network_data = output['centrality_network']

output = kiara.run_job('create.eigenvector_rank_list', inputs={'network_data':network_data})

output
# Out:
# ╭──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │                                                                                                                                          │
# │   field                value                                                                                                             │
# │  ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────  │
# │   centrality_network                                                                                                                     │
# │                        Table: edges                                                                                                      │
# │                                                                                                                                          │
# │                          source                                           target                                           weight        │
# │                         ──────────────────────────────────────────────────────────────────────────────────────────────────────────       │
# │                          Heinsius, Nicolaas, 1620-1681                    Huygens, Christiaan, 1629-1695                   12            │
# │                          Heinsius, Nicolaas, 1620-1681                    Dati, Carlo Roberto, 1619-1676                   6             │
# │                          Heinsius, Nicolaas, 1620-1681                    Boulliau, Ismaël, 1605-1694                      1             │
# │                          Heinsius, Nicolaas, 1620-1681                    Gronovius, Johann Frederick, 1611-1671           1             │
# │                          Heinsius, Nicolaas, 1620-1681                    Chapelain, Jean, 1595-1674                       2             │
# │                          Heinsius, Nicolaas, 1620-1681                    Lubieniecki, Stanisław, 1623-1675                1             │
# │                          Heinsius, Nicolaas, 1620-1681                    Huygens, Constantijn, 1596-1687                  12            │
# │                          Vogelaer, Marcus, b.1589                         Huygens, Constantijn, 1596-1687                  1             │
# │                          Colbert, Jean-Baptiste, 1619-1683                Huygens, Constantijn, 1596-1687                  4             │
# │                          Colbert, Jean-Baptiste, 1619-1683                Huygens, Christiaan, 1629-1695                   2             │
# │                          Colbert, Jean-Baptiste, 1619-1683                Dulaurens, François, fl. 1667-1669               2             │
# │                          Colbert, Jean-Baptiste, 1619-1683                Voye, 1619-1684                                  1             │
# │                          Thorius, Raphael, 1560-1625                      Huygens, Constantijn, 1596-1687                  1             │
# │                          Thorius, Raphael, 1560-1625                      Groot, Hugo de, 1583-1645                        1             │
# │                          Aubespine, François, 1584-1670                   Huygens, Constantijn, 1596-1687                  4             │
# │                          Joachimi, Albert, 1560-1654                      Huygens, Constantijn, 1596-1687                  1             │
# │                          ...                                              ...                                              ...           │
# │                          ...                                              ...                                              ...           │
# │                          Court of Holland, Zeeland and West Friesland,    Huygens, Pieter, fl. 1612                        1             │
# │                          Court of Holland, Zeeland and West Friesland,    Zeeland, States of                               2             │
# │                          Reigersberch, Maria, 1589-1653                   Horn, Gustav Karlsson af Björneborg, 1592-1657   1             │
# │                          Courcelles, Étienne de, 1586-1659                Cupus, Petrus, 1580-1646                         1             │
# │                          Banér, Johann, 1596-1641                         Schörlings, Balthasar, d.1638                    1             │
# │                          Horn, Gustav Karlsson af Björneborg, 1592-1657   Mockhel, Friedrich Richard, d.1646               1             │
# │                          Mockhel, Friedrich Richard, d.1646               Budes, Jean Baptiste, 1602-1643                  1             │
# │                          Goes, Willem, 1613-1688                          Magliabechi, Antonio, 1633-1714                  1             │
# │                          Mencke, Otto, 1644-1707                          Bernoulli, Jacob (I), 1655-1705                  1             │
# │                          Columbus, Johan, 1640-1684                       Bilberg, Johann, 1650-1717                       1             │
# │                          Columbus, Johan, 1640-1684                       Spole, Andreas, 1630-1699                        1             │
# │                          Bruynestein, Jan, 1642-1686                      Liebergen, Diederik, d.1705                      1             │
# │                          Bryas, Charles, 1625-1686                        Campani, Giuseppe, 1635-1715                     1             │
# │                          Boccone, Paolo Silvio, 1633-1704                 Seyen, Arnoldus, 1640-1678                       2             │
# │                          Voogt, Klaas Jansz, d.1696                       Dam, Albert Jansz. van, 1646-1720                1             │
# │                          Zalm, Klaas Dirksz, fl. 1677                     Dam, Albert Jansz. van, 1646-1720                2             │
# │                                                                                                                                          │
# │                        Table: nodes                                                                                                      │
# │                                                                                                                                          │
# │                          Degree Scor   Weighted Be   Weighted Ei   Weighted De   Betweennes   Eigenvector   label        id              │
# │                         ─────────────────────────────────────────────────────────────────────────────────────────────────────────────    │
# │                          7             0.0           0.000648086   67            0.0          0.024083327   Heinsius,    Heinsius, N     │
# │                          1             0.0           5.129942869   2             0.0          0.020295978   Vogelaer,    Vogelaer, M     │
# │                          4             0.0           0.000208376   25            0.0          0.022539013   Colbert, J   Colbert, Je     │
# │                          2             0.0           0.001037103   5             0.0          0.023027205   Thorius, R   Thorius, Ra     │
# │                          1             0.0           0.000205197   4             0.0          0.020295978   Aubespine,   Aubespine,      │
# │                          1             0.0           5.129942869   2             0.0          0.020295978   Joachimi,    Joachimi, A     │
# │                          1             0.0           0.000153898   4             0.0          0.020295978   Zuerius, J   Zuerius, Ja     │
# │                          1             0.0           5.129942869   2             0.0          0.020295978   Vincent, f   Vincent, fl     │
# │                          1             0.0           0.000102598   3             0.0          0.020295978   Ayala, Fer   Ayala, Ferd     │
# │                          2             0.0           0.001037103   4             0.0          0.023027205   Bouricius,   Bouricius,      │
# │                          2             0.0           0.000433541   20            0.0          0.021630033   Balzac, Je   Balzac, Jea     │
# │                          2             0.0           0.000274636   21            0.0          0.021630033   Brasset, J   Brasset, Je     │
# │                          1             0.0           5.129942869   2             0.0          0.020295978   Sandilands   Sandilands,     │
# │                          1             0.0           0.000872090   21            0.0          0.020295978   Hoefnagel,   Hoefnagel,      │
# │                          3             0.000435592   0.009078340   30            4.27117966   0.023729102   Gronovius,   Gronovius,      │
# │                          1             0.0           0.000359096   8             0.0          0.020295978   Pauw, Adri   Pauw, Adria     │
# │                          ...           ...           ...           ...           ...          ...           ...          ...             │
# │                          ...           ...           ...           ...           ...          ...           ...          ...             │
# │                          1             0.0           5.129942869   1             0.0          0.020295978   Schieland,   Schieland,      │
# │                          1             0.0           4.369133873   1             0.0          0.000750240   Jan Harmen   Jan Harmens     │
# │                          1             0.0           5.129942869   1             0.0          0.020295978   Oudewater,   Oudewater,      │
# │                          1             0.0           0.000153898   3             0.0          0.020295978   Drenthe, s   Drenthe, sh     │
# │                          1             0.0           0.000102598   2             0.0          0.020295978   Zaltbommel   Zaltbommel,     │
# │                          1             0.0           0.000985804   1             0.0          0.002731226   Oudart, Ro   Oudart, Rob     │
# │                          1             0.0           0.004929020   5             0.0          0.002731226   Pijnacker,   Pijnacker,      │
# │                          1             0.0           0.001971608   2             0.0          0.002731226   Sande, Joh   Sande, Joha     │
# │                          1             0.0           4.153599116   1             0.0          0.001151335   Suytwijck,   Suytwijck,      │
# │                          1             0.0           5.129942869   1             0.0          0.020295978   Dordrecht,   Dordrecht,      │
# │                          1             0.0           5.129942869   1             0.0          0.020295978   Zwolle, go   Zwolle, gov     │
# │                          1             0.0           4.369133873   1             0.0          0.000750240   Jan Hendri   Jan Hendrik     │
# │                          1             0.0           0.000985804   1             0.0          0.002731226   Amsterdam,   Amsterdam,      │
# │                          1             0.0           4.153599116   1             0.0          0.001151335   Friesland,   Friesland,      │
# │                          1             0.0           0.000985804   1             0.0          0.002731226   Dutch East   Dutch East      │
# │                          1             0.0           0.000985804   1             0.0          0.002731226   Alsace, kn   Alsace, kni     │
# │                                                                                                                                          │
# │   network_result                                                                                                                         │
# │                          Rank   Node                                      Score                    Weighted Eigenvector                  │
# │                         ──────────────────────────────────────────────────────────────────────────────────────────────────               │
# │                          1      Huygens, Constantijn, 1596-1687           0.6964864921689747       0.036713506673830304                  │
# │                          2      Groot, Hugo de, 1583-1645                 0.09372088660871603      0.7052092751282                       │
# │                          3      Huygens, Christiaan, 1629-1695            0.0714878868399279       0.0011296446699229404                 │
# │                          4      Barlaeus, Caspar, 1584-1648               0.057082727940722264     0.037230063313038686                  │
# │                          5      Descartes, René, 1596-1650                0.04577653451928268      0.005521893965439312                  │
# │                          6      Unknown                                   0.03950573755295452      0.029734643909304578                  │
# │                          7      Christina, Queen of Sweden, 1626-1689     0.030550785761979983     0.03908511610290924                   │
# │                          8      Leeuwenhoek, Antoni van, 1632-1723        0.02853594601877094      0.0005269982748835918                 │
# │                          9      Groot, Willem de, 1597-1662               0.027918517076133968     0.4025358631683139                    │
# │                          10     Oldenburg, Henry, 1619-1677               0.027285384393452638     0.0004630555630612593                 │
# │                          11     Wicquefort, Joachim van, 1600-1670        0.026838457519387574     0.09993075150701293                   │
# │                          11     Graswinckel, Theodor, 1600-1666           0.026838457519387574     0.009483026175618282                  │
# │                          13     Mersenne, Marin, 1588-1648                0.026820699785950232     0.0026939354604370164                 │
# │                          14     Beverwijck, Johan van, 1594-1647          0.02602479287206717      0.002698227593478118                  │
# │                          15     Sorbière, Samuel, 1615-1670               0.025950915508605076     0.002024817632971513                  │
# │                          16     Nierop, Dirck Rembrantsz van, 1610-1682   0.025742184515403374     0.00031263767240864525                │
# │                          ...    ...                                       ...                      ...                                   │
# │                          ...    ...                                       ...                      ...                                   │
# │                          1895   Wingendorp, Herman, fl. 1655-1680         4.5086912545978935e-05   3.8042086833780764e-08                │
# │                          1895   Slade, Matthew, 1628-1689                 4.5086912545978935e-05   1.9021043416890382e-08                │
# │                          1895   Lindt, Ewoud de, 1645-1683                4.5086912545978935e-05   1.9021043416890382e-08                │
# │                          1895   Genet, Hille, fl. 1674                    4.5086912545978935e-05   1.9021043416890382e-08                │
# │                          1895   Schrader, Justus, 1646-1712               4.5086912545978935e-05   1.9021043416890382e-08                │
# │                          1895   Malebranche, Nicolas, 1638-1715           4.5086912545978935e-05   1.9021043416890382e-08                │
# │                          1895   Guenellon, Pieter, 1650-1722              4.5086912545978935e-05   1.9021043416890382e-08                │
# │                          1895   Tiellens, Jan, 1623-1681                  4.5086912545978935e-05   1.9021043416890382e-08                │
# │                          1895   De Graaf, Regnier, 1641-1673              4.5086912545978935e-05   3.8042086833780764e-08                │
# │                          1895   Stensen, Niels, 1638-1686                 4.5086912545978935e-05   5.706313025067115e-08                 │
# │                          1907   Mencke, Otto, 1644-1707                   3.6391990424248906e-05   5.815375904756289e-08                 │
# │                          1908   Liebergen, Diederik, d.1705               3.358062740936717e-05    5.80504171417201e-08                  │
# │                          1909   Fabri, Honoré de, 1607-1688               1.964737021653703e-05    1.0199282658183553e-09                │
# │                          1910   Bilberg, Johann, 1650-1717                1.9055211591537067e-05   4.0677077616600653e-10                │
# │                          1910   Spole, Andreas, 1630-1699                 1.9055211591537067e-05   4.0677077616600653e-10                │
# │                          1912   Zalm, Klaas Dirksz, fl. 1677              2.467489027988409e-06    2.6368460524014296e-11                │
# │                                                                                                                                          │
# │                                                                                                                                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# As before, we have our score table and our updated node attributes. Great!
#
# There's one final centrality measure in the network analysis plugin for closeness. See if you can work out how to check the information for this and run it on the network here, or feel free to move on to other measures.
#
# <b>Modularity Group</b>
# <br>This next module determines the modularity groups in the network, again assigning each group as a node attribute. Let's have a look at the parameters for it.

# %%
kiara.retrieve_operation_info('compute.modularity_group')
# Out:
#
#  Author(s)
#                      Lena Jaskov         helena.jaskov@uni.lu
#                      Markus Binsteiner   markus@frkl.io
#
#  Context
#                      Tags         dh_tagung_2023
#                      Labels       package: kiara_plugin.dh_tagung_2023
#                      References   source_repo: ]8;id=257534;https://github.com/DHARPA-Project/kiara_plugin.dh_tagung_2023\https://github.com/DHARPA-Project/kiara_plugin.dh_tagung_2023]8;;\
#                                   documentation: ]8;id=852471;https://DHARPA-Project.github.io/kiara_plugin.dh_tagung_2023/\https://DHARPA-Project.github.io/kiara_plugin.dh_tagung_2023/]8;;\
#
#  Operation details
#                      Documentation   Calculate modularity for each node and attach modularity group number to node list as attribute.
#
#                                      This networkX based function uses Clauset-Newman-Moore greedy modularity maximization to find the
#                                      community partition with the largest modularity.
#
#                                      Modularity community is a density-based community detection method that investigates the structural
#                                      composition of a network.
#
#                      Inputs
#                                        field name              type           description                   Required   Default
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        network_data            network_data   The network data to           yes        -- no default --
#                                                                               analyze.
#                                        number_of_communities   integer        Number of communities into    no         -- no default --
#                                                                               which the network should be
#                                                                               partitioned. This is a user
#                                                                               defined number that can be
#                                                                               above or below maximum
#                                                                               modularity.
#
#
#                      Outputs
#                                        field name           type           description
#                                       ──────────────────────────────────────────────────────────────────────────────────────────────────
#                                        modularity_network   network_data   Updated network data with modularity group assigned as a
#                                                                            node attribute.
#                                        maximum_modularity   integer        The number of communities at which maximum modularity is
#                                                                            reached for this network. If the 'number_of_communities' is
#                                                                            manually set, this number might deviate from the manually
#                                                                            computed number.

# %% [markdown]
# Here, we can set the number of communities that we want the module to divide our network up into, or we can allow the code to find this automatically.
#
# Let's give it a go with our network once more.

# %%
network_data = output['centrality_network']

output = kiara.run_job('compute.modularity_group', inputs={'network_data':network_data})

output

# %% [markdown]
# Great - this once again gives us our updated network, and also tells us how many modularity groups the measure has found in the network.
#
# Let's look at one last measure.
#
# <b>Cut Points</b>
# This last function finds all the cut-points in the network, nodes that when removed will separate the component into two or more pieces. This function will return a list of the cut-points, and assign 'Yes' or 'No' as a node attribute.
#
# Let's have a look one last time.

# %%
kiara.retrieve_operation_info('create.cut_point_list')

# %% [markdown]
# Nice and simple, no extra parameters: it just needs our network.

# %%
network_data = output['modularity_network']

output = kiara.run_job('create.cut_point_list', inputs={'network_data':network_data})

output

# %% [markdown]
# Having started simply with an imported CSV of letter edges, we've now got a lot of information. This is great - but what next?
#
# <h2>Exporting the Network</h2>
#
# <i>kiara</i> has stored all of this information we have just created, and as it's interoperable, it also allows us to export this network again. We can export all this network data as a set of CSVs or even graphml with built in <i>kiara</i> modules like this:

# %%
kiara.retrieve_operation_info('export.network_data.as.graphml_file')

# %% [markdown]
# Let's export our final network after the cut-points measures then, and save it locally.

# %%
network_data = output['cut_network']

output = kiara.run_job('export.network_data.as.graphml_file', inputs={'network_data':network_data, 'name':'CKCC_kiara_network'})

# %% [markdown]
# Now that we've done that, we can use NetworkX to visualise our final graph. Though it's difficult to see properly given the scale of the network, it's nice to visualise what we've been working with!

# %%
network = nx.read_graphml('CKCC_kiara_network.graphml')
nx.draw(network)

# %% [markdown]
# Finally we can check out the lineage for our final export output. As we can see, it has stored all the decisions we have made, and the ways in which they have created 'new' datasets, right from our original import.

# %%
from kiara_plugin.dh_tagung_2023.utils import augment_lineage_data

# %%
augmented_nodes = augment_lineage_data(output['export_details'],kiara)

# %%
from observable_jupyter import embed

# %%
embed('@dharpa-project/kiara-data-lineage', cells=['displayViz', 'style'], inputs={'dataset':augmented_nodes, 'modulesNodes':12, 'valueNodes':7, 'Width': 260, 'Height': 500})

# %% [markdown]
# <h2>Recommended Reading</h2>
# <br>Want to know more about Network Analysis? Here's some helpful tutorials and reading:
#
# * <a href="https://programminghistorian.org/en/lessons/exploring-and-analyzing-network-data-with-python"><i>Programming Historian</i> NetworkX tutorial</a>
# * Ahnert, Ruth, Ahnert, Sebastian E., Coleman, Catherine Nicole and Scott B. Weingart 2020. <i>The Network Turn: The Changing Perspectives in the Humanities</i>. Cambridge: Cambridge University Press. https://doi.org/10.1017/9781108866804
# * Barabási, Albert-László. <i>Linked: The New Science of Networks</i>. New York: Penguin Group, 2002.
# * Borgatti, Stephen. ‘The Key Player Problem.’ In <i>Dynamic Social Network Modeling and Analysis: Workshop Summary and Papers</i>. Edited by Ronald Breiger, Kathleen Carley and Philippa Pattison. Washington: The National Acadamies Press, 2003. 241-252.
# * Brughmans, Tom, Anna Collar, and Fiona Coward, ed. <i>The Connected Past: Challenges to Network Studies in Archaeology and History</i>. Oxford: Oxford University Press, 2016.
# * Tuominen, Jouni, Koho, Mikko, Pikkanen, Ilona, Drobac, Senka, Enqvist, Johanna, Hyvönen, Eero, La Mela, Matti, Leskinen, Petri, Paloposki, Hanna-Leena and Rantala, Heikki. Constellations of Correspondence: a Linked Data Service and Portal for Studying Large and Small Networks of Epistolary Exchange in the Grand Duchy of Finland. DHNB 2022 The 6th Digital Humanities in Nordic and Baltic Countries Conference, pp. 415-423, CEUR Workshop Proceedings, Vol. 3232, March, 2022. http://ceur-ws.org/Vol-3232/paper41.pdf
